# %%
# !pip install bs4
# !pip install lxml
# !pip install requests

# %%
import os
import sys
import re
import requests
import time

from bs4 import BeautifulSoup
from pprint import pprint

# %%
url_basic_base = 'http://movie.naver.com/movie/bi/mi/basic.nhn?code=%s'

# %%
movie_id = 150198 # 너의 이름은

# %%
url = url_basic_base % movie_id
req = requests.get(url)
html = req.text

## parsing
data = BeautifulSoup(html, "html.parser") # data = BeautifulSoup(html, 'lxml')

# %% [markdown]
# # scraping test

# %%
data
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="no" http-equiv="imagetoolbar">
# <title>너의 이름은. : 네이버 영화</title>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image"/>
# <meta content="네이버영화 너의 이름은." property="me2:post_tag"/>
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="너의 이름은." property="me2:category2"/>
# <meta content="너의 이름은." property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="http://movie.naver.com/movie/bi/mi/basic.nhn?code=150198" property="og:url"/>
# <meta content="http://movie.phinf.naver.net/20161208_214/1481159570776FFFlp_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content="천년 만에 다가오는 혜성기적이 시작된다_도쿄에 사는 소년 ‘타키’와 시골에 사는 소녀 ‘미츠하’는..." property="og:description"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# <meta content="네이버 영화" property="og:article:author"/>
# <meta content="http://movie.naver.com/" property="og:article:author:url"/>
# <link href="http://static.naver.net/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="/css/deploy/movie.all.css?20170426143858" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20170426143858" type="text/javascript"></script>
# </link></meta></meta></meta></head>
# <body>
# <div class="basic" id="wrap">
# <!-- GNB -->
# <script type="text/javascript">
# function delayed_submit(object) {
# 	if (navigator.userAgent.indexOf('MSIE') == -1) {
# 		var b = c = new Date();
#       	while ((b.getTime() - c.getTime()) < 100) {
# 			b = new Date();
#       	}
# 	}
# }
# </script>
# <script type="text/javascript">
# 	var gnb_service = "movie";
# 	var gnb_logout = "http://movie.naver.com/movie/bi/mi/basic.nhn%3Fcode%3D150198";
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness=3;
# 	var gnb_response = true;
#
# 	jindo.$Fn(function(){
# 		getGNB();
# 	}).attach(window, "load");
#
# 	jindo.$Fn(function(oEvent){ var welSource = jindo.$Element(oEvent.element);
# 			if (!welSource.isChildOf(jindo.$Element("gnb"))) {
# 				gnbAllLayerClose();
# 			}
# 	}).attach(document, 'click');
# </script>
# <!-- skip navigation -->
# <div id="u_skip">
# <a href="#header" onclick="document.getElementById('header').tabIndex=-1;document.getElementById('header').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" id="gnb_goContent" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <!-- //skip navigation -->
# <div class="gnb_container">
# <div class="gnb_content">
# <div class="gnb_box">
# <div class="gnb_wrap">
# <div id="gnb">
# <script charset="utf-8" src="http://static.gn.naver.net/template/gnb_utf8.nhn" type="text/javascript"></script>
# </div>
# </div>
# <!-- 검색창 -->
# <form action="/movie/search/result.nhn" id="jSearchForm" method="get" style="margin:0;display:none;">
# <input maxlength="100" name="query" type="text"/>
# <input name="section" type="hidden" value="all"/>
# <input name="ie" type="hidden" value="utf8"/>
# </form>
# <fieldset class="srch_area" id="jSearchArea">
# <legend><span class="blind">영화검색 영역</span></legend>
# <div class="srch_field_on _view">
# <span class="ipt_srch">
# <label for="ipt_tx_srch" id="search_placeholder">영화검색</label>
# <input accesskey="s" autocomplete="off" class="ipt_tx_srch" id="ipt_tx_srch" maxlength="100" name="query" style="ime-mode:active;" type="text"/>
# <span class="align"></span>
# <span class="auto_tx"><a href="#" title="자동완성 펼치기"><img alt="자동완성 펼치기" height="4" src="http://static.naver.net/movie/2012/06/srch_arrow_down.gif" title="자동완성 펼치기" width="7"/></a></span>
# </span>
# <button class="btn_srch" onclick="clickcr(this,'GNB.search','','',event); delayed_submit(this);" title="검색" type="submit"><span class="blind">검색</span></button>
# <!-- 자동 완성 영역임 #autocomplate_template-->
# </div>
# </fieldset>
# <!-- //검색창 -->
# </div>
# </div>
# </div>
# <!-- //GNB -->
# <!-- header -->
# <div id="header">
# <a class="blind" href="#content" title="본문으로 이동">본문 바로가기</a>
# <h1 class="svc_name">
# <a class="ci_logo" href="http://www.naver.com/" id="lnb_gonaver" title="naver로 바로가기"><img alt="NAVER" height="13" src="http://static.naver.net/movie/2013/07/logo_ci.png" width="62"/></a><!-- N=a:LNB.naver -->
# <a class="svc_logo" href="/" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="http://static.naver.net/movie/2012/06/logo_svc.png" width="34"/></a><!-- N=a:LNB.movie -->
# </h1>
# <div class="scrollbar scrollbar-noscript" id="scrollbar">
# <div class="scrollbar-box">
# <div class="scrollbar-content">
# <div class="in_scroll">
# <ul class="navi">
# <li>
# <a class="menu01" href="/" title="영화홈"><strong>영화홈</strong></a><!-- N=a:LNB.home -->
# </li>
# <li>
# <a class="menu02_on" href="/movie/running/current.nhn" title="상영작·예정작"><strong>상영작·예정작</strong></a><!-- N=a:LNB.movies -->
# <ul class="navi_sub" id="navi_movie" style="display:none">
# <li><a class="sub2_1_on" href="/movie/running/current.nhn" title="현재 상영영화"><em>현재 상영영화</em></a><!-- N=a:LNB.now --></li>
# <li><a class="sub2_2" href="/movie/running/premovie.nhn" title="개봉 예정영화"><em>개봉 예정영화</em></a><!-- N=a:LNB.soon --></li>
# <li><a class="sub2_3" href="/movie/running/weekendmovie.nhn" title="TV/DVD 영화"><em>TV/DVD 영화</em></a><!-- N=a:LNB.guide --></li>
# <li><a class="sub2_4" href="/movie/running/movieclip.nhn" title="예고편"><em>예고편</em></a><!-- N=a:LNB.tailer --></li>
# </ul>
# </li>
# <li>
# <a class="menu03" href="/movie/sdb/rank/rmovie.nhn" title="영화랭킹"><strong>영화랭킹</strong></a><!-- N=a:LNB.db -->
# </li>
# <li>
# <a class="menu05" href="/movie/bi/mi/reserve.nhn" title="예매"><strong>예매</strong></a><!-- N=a:LNB.ticket -->
# </li>
# <li>
# <a class="menu06" href="/movie/preview/index.nhn" title="시사회·이벤트"><strong>시사회·이벤트</strong></a><!-- N=a:LNB.event -->
# </li>
# <li>
# <a class="menu07" href="/movie/point/af/list.nhn" title="평점·리뷰"><strong>평점·리뷰</strong></a><!-- N=a:LNB.comm -->
# </li>
# <li>
# <a class="menu08" href="http://nstore.naver.com/movie/home.nhn" target="_blank" title="다운로드"><strong>다운로드</strong></a><!-- N=a:LNB.download -->
# </li>
# <li class="nav_indi">
# <a href="/movie/indifilm/festival.nhn" title="인디극장"><strong>인디극장</strong></a><!-- N=a:LNB.indie -->
# </li>
# </ul>
# <!-- [D] view 모드 전환간 클래스는 _on,_off / 비활성화는 _disabled -->
# <div class="lnb_etc" id="viewmode-option-area">
# <div class="info_view">
# <a class="_info-anchor btn_view_md" href="#"><em>보기옵션</em></a>
# <div class="ly_info_view" id="_viewmode-option-info-layer" style="display:none">
# <span></span>
# 										브라우저의 해상도에 따라 기본 혹은 넓게보기가 가능합니다. 넓게보기는 가로해상도 1872픽셀 이상에서만 동작합니다.
# 									</div>
# </div>
# <div class="view_mode">
# <a class="_basic-btn normal_on" href="#" title=""><em>기본보기</em></a>
# <a class="_wide-btn wide_off" href="#" title=""><em>넓게보기</em></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="scrollbar-v">
# <div class="scrollbar-button-up"></div>
# <div class="scrollbar-track">
# <div class="scrollbar-thumb"></div>
# </div>
# <div class="scrollbar-button-down"></div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	if ("현재 상영영화" == "상영작·예정작"
# 			|| "현재 상영영화" == "현재 상영영화"
# 			|| "현재 상영영화" == "개봉 예정영화"
# 			|| "현재 상영영화" == "TV/DVD 영화"
# 			|| "현재 상영영화" == "예고편") {
# 		jindo.$Element("navi_movie").show();
# 	}
# 	</script>
# <!-- //header -->
# <!-- container -->
# <div id="container">
# <!-- 프로모션 레이어 -->
# <div class="ly_promo" id="thumb_promotion_layer"><h3>원하시는 영화를 선택해보세요.</h3>
# 			화제가 되고 있는 최신영화 정보를 한 눈에 확인하실 수 있습니다.
# 			<a class="btn_clse" href="#" id="thumb_promotion_layer_close" title="닫기">닫기</a>
# </div>
# <!-- 상단 현재 상영작 썸네일 리스트 -->
# <div class="spot">
# <div class="top_list" id="_TopArea">
# <div class="first_mv_list current_mv_list _mv_default_list">
# <button class="_prev-btn thumb_prev" onclick="clickcr(this,'rnk.prev','','',event);" type="button"><em>이전</em></button>
# <a class="h_current_mv" href="/movie/running/current.nhn?order=reserve" id="first_mv_list_link"><h2><strong class="blind">상영작 예매순위</strong></h2></a><!-- N=a:rnk.ntitle -->
# <div class="top_poster_area">
# <ul class="top_thumb_lst">
# <li data-title="특별시민"><a href="/movie/bi/mi/basic.nhn?code=146485"><img alt="특별시민" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170419_128/1492582031650Pk5Iq_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="임금님의 사건수첩"><a href="/movie/bi/mi/basic.nhn?code=144280"><img alt="임금님의 사건수첩" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170426_111/14931684846956pCQV_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="분노의 질주: 더 익스트림"><a href="/movie/bi/mi/basic.nhn?code=140731"><img alt="분노의 질주: 더 익스트림" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170314_17/1489464877358bXa3j_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="스머프: 비밀의 숲"><a href="/movie/bi/mi/basic.nhn?code=118966"><img alt="스머프: 비밀의 숲" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170428_97/1493358197366gAMdD_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="미녀와 야수"><a href="/movie/bi/mi/basic.nhn?code=136872"><img alt="미녀와 야수" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170207_61/14864349974992zXL8_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="아빠는 딸"><a href="/movie/bi/mi/basic.nhn?code=143473"><img alt="아빠는 딸" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170323_62/1490230691455MpGoC_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="더 플랜"><a href="/movie/bi/mi/basic.nhn?code=162471"><img alt="더 플랜" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170412_173/1491959905447VUvV0_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="서서평, 천천히 평온하게"><a href="/movie/bi/mi/basic.nhn?code=160135"><img alt="서서평, 천천히 평온하게" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170320_65/1489970121837vBFPN_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국"><a href="/movie/bi/mi/basic.nhn?code=161374"><img alt="리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170414_75/1492133942177M1ROX_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="오두막"><a href="/movie/bi/mi/basic.nhn?code=125447"><img alt="오두막" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170329_88/1490752562935uCPQL_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="댄서"><a href="/movie/bi/mi/basic.nhn?code=153621"><img alt="댄서" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170313_223/1489370597182oNls4_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="극장판 쿠로코의 농구 라스트 게임"><a href="/movie/bi/mi/basic.nhn?code=156185"><img alt="극장판 쿠로코의 농구 라스트 게임" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170414_125/1492154333194H9k8h_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="나의 사랑, 그리스"><a href="/movie/bi/mi/basic.nhn?code=147896"><img alt="나의 사랑, 그리스" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170331_118/14909218697169uaFc_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="나는 부정한다"><a href="/movie/bi/mi/basic.nhn?code=144984"><img alt="나는 부정한다" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170327_256/1490577895207PxiiP_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="히든 피겨스"><a href="/movie/bi/mi/basic.nhn?code=147092"><img alt="히든 피겨스" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170323_41/14902311518230x8pp_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# </ul>
# </div>
# <button class="_next-btn thumb_next" onclick="clickcr(this,'rnk.next','','',event);" type="button"><em>다음</em></button>
# </div>
# <div class="second_mv_list expected_mv_list _mv_default_list">
# <button class="_prev-btn thumb_prev" onclick="clickcr(this,'rnk.prev','','',event);" type="button"><em>이전</em></button>
# <a class="h_expected_mv" href="/movie/running/premovie.nhn" id="second_mv_list_link"><h2><strong class="blind">예정작 개봉일순</strong></h2></a><!-- N=a:rnk.stitle -->
# <div class="top_poster_area">
# <ol class="top_thumb_lst">
# <li data-title="무협양축 검접"><a href="/movie/bi/mi/basic.nhn?code=51819"><img alt="무협양축 검접" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170426_126/1493174657278T6xql_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="가디언즈 오브 갤럭시 VOL. 2"><a href="/movie/bi/mi/basic.nhn?code=127398"><img alt="가디언즈 오브 갤럭시 VOL. 2" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170329_6/1490752948552vH5G8_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="보스 베이비"><a href="/movie/bi/mi/basic.nhn?code=129094"><img alt="보스 베이비" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170419_211/14925635918940f3dx_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="보안관"><a href="/movie/bi/mi/basic.nhn?code=146524"><img alt="보안관" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170404_270/14912701138864TMXE_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="슈퍼 빼꼼: 스파이 대작전"><a href="/movie/bi/mi/basic.nhn?code=94183"><img alt="슈퍼 빼꼼: 스파이 대작전" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170328_207/1490661900196ObqpA_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="극장판 마이 리틀 포니: 이퀘스트리아 걸스"><a href="/movie/bi/mi/basic.nhn?code=109606"><img alt="극장판 마이 리틀 포니: 이퀘스트리아 걸스" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170424_163/1493024434058pVBhL_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="오즈의 마법사 2"><a href="/movie/bi/mi/basic.nhn?code=161323"><img alt="오즈의 마법사 2" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170419_210/1492585270938pzgy7_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="언노운 걸"><a href="/movie/bi/mi/basic.nhn?code=150372"><img alt="언노운 걸" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170411_20/1491894131972YMzIy_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="악마는 프라다를 입는다"><a href="/movie/bi/mi/basic.nhn?code=60484"><img alt="악마는 프라다를 입는다" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170421_168/1492761621282U7CYn_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="음양팔괘장: 6인의 고수"><a href="/movie/bi/mi/basic.nhn?code=158494"><img alt="음양팔괘장: 6인의 고수" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170421_147/1492759268066Gr3JY_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="소림사 무림쟁패"><a href="/movie/bi/mi/basic.nhn?code=163124"><img alt="소림사 무림쟁패" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170428_177/1493355577671e1ekB_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="언노운 콜"><a href="/movie/bi/mi/basic.nhn?code=158709"><img alt="언노운 콜" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170413_59/1492069092293w6m1B_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="추격자: 침묵의 살인"><a href="/movie/bi/mi/basic.nhn?code=80127"><img alt="추격자: 침묵의 살인" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170426_172/1493194266031tvOfp_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="분노의 전차군단"><a href="/movie/bi/mi/basic.nhn?code=163126"><img alt="분노의 전차군단" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170428_125/1493357790064pipgD_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="에이리언: 커버넌트"><a href="/movie/bi/mi/basic.nhn?code=99715"><img alt="에이리언: 커버넌트" height="60" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170421_256/1492756975428P3mAD_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# </ol>
# </div>
# <button class="_next-btn thumb_next" onclick="clickcr(this,'rnk.next','','',event);" type="button"><em>다음</em></button>
# </div>
# <a class="open_lst _expand-btn" href="#"><em class="blind" id="expandButtonName">상영예매순위, 예정작 개봉일순 더보기</em></a><!-- N=a:rnk.open -->
# <div class="open_mv_list _expansion-wrap" style="display:none">
# <div class="current_open">
# <div class="open_title_area">
# <h2 class="h_current_open">상영작 예매순위</h2>
# <a class="open_more" href="/movie/running/current.nhn?order=reserve" title="더보기"><em>더보기</em></a><!-- N=a:rnk.nmore -->
# </div>
# <ul class="current_list">
# <li><a href="/movie/bi/mi/basic.nhn?code=146485" title="특별시민"><img alt="특별시민" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170419_128/1492582031650Pk5Iq_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=144280" title="임금님의 사건수첩"><img alt="임금님의 사건수첩" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170426_111/14931684846956pCQV_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=140731" title="분노의 질주: 더 익스트림"><img alt="분노의 질주: 더 익스트림" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170314_17/1489464877358bXa3j_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=118966" title="스머프: 비밀의 숲"><img alt="스머프: 비밀의 숲" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170428_97/1493358197366gAMdD_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=136872" title="미녀와 야수"><img alt="미녀와 야수" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170207_61/14864349974992zXL8_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=143473" title="아빠는 딸"><img alt="아빠는 딸" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170323_62/1490230691455MpGoC_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=162471" title="더 플랜"><img alt="더 플랜" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170412_173/1491959905447VUvV0_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=160135" title="서서평, 천천히 평온하게"><img alt="서서평, 천천히 평온하게" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170320_65/1489970121837vBFPN_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=161374" title="리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국"><img alt="리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170414_75/1492133942177M1ROX_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=125447" title="오두막"><img alt="오두막" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170329_88/1490752562935uCPQL_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=153621" title="댄서"><img alt="댄서" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170313_223/1489370597182oNls4_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=156185" title="극장판 쿠로코의 농구 라스트 게임"><img alt="극장판 쿠로코의 농구 라스트 게임" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170414_125/1492154333194H9k8h_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=147896" title="나의 사랑, 그리스"><img alt="나의 사랑, 그리스" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170331_118/14909218697169uaFc_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=144984" title="나는 부정한다"><img alt="나는 부정한다" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170327_256/1490577895207PxiiP_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=147092" title="히든 피겨스"><img alt="히든 피겨스" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170323_41/14902311518230x8pp_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=137976" title="파운더"><img alt="파운더" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170328_244/1490663193916weWkH_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=97857" title="가디언즈 오브 갤럭시"><img alt="가디언즈 오브 갤럭시" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20140722_148/1405989759821lDURD_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=158578" title="흑집사 : 북 오브 더 아틀란틱"><img alt="흑집사 : 북 오브 더 아틀란틱" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170407_153/1491527295172laUdr_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=39723" title="클로저"><img alt="클로저" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170411_236/14918864122309UDYp_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=126214" title="런던 프라이드"><img alt="런던 프라이드" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170412_95/1491986330663NvBw0_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# </ul>
# </div>
# <div class="expected_open">
# <div class="open_title_area">
# <h2 class="h_expected_open">예정작 개봉일순</h2>
# <a class="open_more" href="/movie/running/premovie.nhn" title="더보기"><em>더보기</em></a><!-- N=a:rnk.smore -->
# </div>
# <ol class="current_list">
# <li><a href="/movie/bi/mi/basic.nhn?code=51819" title="무협양축 검접"><img alt="무협양축 검접" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170426_126/1493174657278T6xql_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=127398" title="가디언즈 오브 갤럭시 VOL. 2"><img alt="가디언즈 오브 갤럭시 VOL. 2" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170329_6/1490752948552vH5G8_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=129094" title="보스 베이비"><img alt="보스 베이비" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170419_211/14925635918940f3dx_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=146524" title="보안관"><img alt="보안관" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170404_270/14912701138864TMXE_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=94183" title="슈퍼 빼꼼: 스파이 대작전"><img alt="슈퍼 빼꼼: 스파이 대작전" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170328_207/1490661900196ObqpA_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=109606" title="극장판 마이 리틀 포니: 이퀘스트리아 걸스"><img alt="극장판 마이 리틀 포니: 이퀘스트리아 걸스" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170424_163/1493024434058pVBhL_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=161323" title="오즈의 마법사 2"><img alt="오즈의 마법사 2" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170419_210/1492585270938pzgy7_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=150372" title="언노운 걸"><img alt="언노운 걸" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170411_20/1491894131972YMzIy_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=60484" title="악마는 프라다를 입는다"><img alt="악마는 프라다를 입는다" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170421_168/1492761621282U7CYn_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=158494" title="음양팔괘장: 6인의 고수"><img alt="음양팔괘장: 6인의 고수" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170421_147/1492759268066Gr3JY_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=163124" title="소림사 무림쟁패"><img alt="소림사 무림쟁패" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170428_177/1493355577671e1ekB_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=158709" title="언노운 콜"><img alt="언노운 콜" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170413_59/1492069092293w6m1B_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=80127" title="추격자: 침묵의 살인"><img alt="추격자: 침묵의 살인" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170426_172/1493194266031tvOfp_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=163126" title="분노의 전차군단"><img alt="분노의 전차군단" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170428_125/1493357790064pipgD_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=99715" title="에이리언: 커버넌트"><img alt="에이리언: 커버넌트" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170421_256/1492756975428P3mAD_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=127346" title="석조저택 살인사건"><img alt="석조저택 살인사건" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170417_186/149240333802514kQW_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=153964" title="목소리의 형태"><img alt="목소리의 형태" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170419_128/1492579106081DlvO1_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=35626" title="8 마일"><img alt="8 마일" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170407_58/1491550805916wTKgG_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=149059" title="세일즈맨"><img alt="세일즈맨" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie.phinf.naver.net/20170418_271/1492477077850cRMl4_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=152387" title="컴, 투게더"><img alt="컴, 투게더" height="110" onerror="src='http://static.naver.net/movie/2012/06/dft_img77x110.png'" src="http://movie2.phinf.naver.net/20170412_45/1491961498146n9ImJ_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# </ol>
# </div>
# </div>
# </div>
# </div>
# <!-- //상단 현재 상영작 썸네일 리스트 -->
# <script id="_TopAreaThumbnailExpander_tpl" type="text/template">
#             <div class="zoom_img" style="width:77px;height:110px;left:{=nLeft}px">
#                 <a href="{=sUrl}">
#                     <span class="img_mask">
#                             <p>{=sTitle}</p>
#                     </span>
#                     <img src="{=sImgSrc}" alt="" />
#                 </a>
#             </div>
#         </script>
# <script type="text/javascript">
# 			jindo.$Fn(
# 				function (we) {
# 					if (jindo.$('thumb_promotion_layer') != null) {
# 						jindo.$Fn(
# 							function(e) {
# 								jindo.$Element("thumb_promotion_layer").hide();
# 								jindo.$Cookie().set("NM_THUMB_PROMOTION_BLOCK", "Y", 1000);	//1000 days
# 							}
# 						).attach(jindo.$("thumb_promotion_layer_close"), "click").attach(jindo.$("_TopArea"), "click");
# 					}
# 				}
# 			).attach(document, 'domready');
#         </script>
# <!-- content -->
# <div id="content">
# <div class="article">
# <!-- 영화정보(wide) -->
# <div class="wide_info_area" style="display: none">
# <!-- 포스터 -->
# <div class="poster">
# <a href="#" onclick="javascript:common.iwopen('150198');clickcr(this,'ifo.img','','',event);return false;"><img alt="너의 이름은." onerror="this.src='http://static.naver.net/movie/2012/06/dft_img77x110_1.png'" src="http://movie2.phinf.naver.net/20161208_214/1481159570776FFFlp_JPEG/movie_image.jpg?type=m77_110_2"/><span>포스터 크게보기</span></a>
# </div>
# <!-- //포스터 -->
# <div class="mv_info">
# <h3 class="h_movie">
# <a href="./basic.nhn?code=150198">너의 이름은.</a><!-- N=a:ifo.title -->
# <a class="opening" href="/movie/running/current.nhn?order=reserve"><em>상영중</em></a><!-- N=a:ifo.nbtn -->
# <strong class="h_movie2" title="君の名は。									, your name.										, 					2016">君の名は。
#
# 					, your name.
#
# 					,
# 					2016</strong>
# </h3>
# <div class="main_score">
# <div class="score">
# <div class="uio_ntz_btn see">
# <span class="ntz _actualPointHelpWide">
# <em class="blind">관람객 평점</em>
# <a class="help _actualPointHelpWide" href="#" id="actualPointHelpButtonWide">관람객 평점 도움말</a>
# </span>
# <div class="ly_ntz _actualPointHelpWide" id="actualPointHelpWide" style="display:none">
# <span></span>
# 							관람객 평점은 네이버영화에서<br>예매하고 실제 관람 후 이용자들이<br>작성한 평점입니다.
# 							<button class="btn_close _actualPointHelpWide" id="actualPointHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </br></br></div>
# <div class="ly_count" id="actualPointCountWide" style="display:none">
# <span></span>
# 							참여 <em>10,839</em>명
# 						</div>
# </div>
# <a class="ntz_score" href="./point.nhn?code=150198&amp;onlyActualPointYn=Y#pointAfterTab" id="actualPointPersentWide">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.2%">관람객 평점 9.02점</span></span><em class="num9">9</em><em class="dot">.</em><em class="num0">0</em><em class="num2">2</em>
# </div>
# </a><!-- N=a:ifo.mgrating -->
# </div>
# <div class="score">
# <div class="spc_score_area">
# <a class="spc" href="./point.nhn?code=150198#pointExpertTab">
# <span class="spc_score"><em class="blind">기자 · 평론가 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:71.7%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num1">1</em><em class="num7">7</em>
# </div>
# </a><!-- N=a:ifo.crating -->
# </div>
# </div>
# <div class="score">
# <div class="uio_ntz_btn">
# <span class="ntz">
# <em class="blind">네티즌 평점</em><a class="help" href="#" id="pointHelpButtonWide" title="네티즌 평점 도움말 보기">네티즌 평점 도움말</a>
# </span>
# <div class="ly_ntz _pointHelpWide" id="pointHelpWide" style="display:none">
# <span></span>
#
#
#
# 								국내 개봉작입니다. 관람하신 영화에 대한<br> 평점을 남겨주세요. 140자평 뿐 아니라 블<br>로그 영화 리뷰작성 시 등록한 별점도 함께<br> 반영됩니다.
#
#
# 						<button class="btn_close _pointHelpWide" id="pointHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </br></br></br></div>
# <div class="ly_count" id="pointNetizenCountWide" style="display:none">
# <span></span>
# 						참여 <em>28,379</em>명
# 					</div>
# </div>
# <div class="star_score ">
# <a href="./point.nhn?code=150198#pointAfterTab" id="pointNetizenPersentWide"><span class="st_off"><span class="st_on" style="width:88.1%"></span></span><em class="num8">8</em><em class="dot">.</em><em class="num8">8</em><em class="num1">1</em></a><!-- N=a:ifo..arating -->
# </div>
# </div>
# <div class="score" id="noPointWide">
# <div class="my_score_area">
# <!--[D] 내평점이 없는경우 화살표를 없애기 위해 class="my"가 빠진다 -->
# <a href="./point.nhn?code=150198#pointAfterTab">
# <span class="my_score"><em class="blind">내 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:0%">0점</span></span>
# <span class="btn_write">등록</span>
# </div>
# </a>
# </div>
# </div>
# <div class="score" id="existPointWide" style="display : none">
# <div class="my_score_area">
# <a class="my" href="javascript:pointWide.toggleMyPoint();">
# <span class="my_score">
# <em class="blind">내 평점</em>
# </span>
# <div class="star_score" id="starPointWide">
# <span class="st_off"><span class="st_on" id="pointStarWide" style="width:0%"></span></span>
# </div>
# </a><!-- N=a:ifo.marating -->
# <div class="ly_my" id="myPointLayerWide" style="display:none">
# <span id="pointTextWide"></span><a class="btn_del" href="javascript:checkAlreadyPointAfterExist('wide', );" id="pointRemoveWide">삭제</a>
# <a class="btn_close" href="javascript:pointWide.toggleMyPoint();"><em>닫기</em></a>
# </div>
# </div>
# </div>
# </div>
# <p class="info_spec">
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a>,
#
#
#
# 				<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a>,
#
#
#
# 				<a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a>
# </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?nation=JP">일본</a>
# </span>
# <span>106분 </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=2017">2017</a>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=20170104">.01.04</a> 개봉
#
#
#
# 				</span>
# <span>
# 					[국내]
#
# 							<a href="/movie/sdb/browsing/bmovie.nhn?grade=1001002">12세 관람가</a>
# </span>
# <span class="uio_ntz_btn">
# <span class="ntz">누적관객<a class="help" href="#" id="boxofficeHelpButtonWide" title="누적관객 도움말 보기">누적관객 도움말</a></span>
# <span class="ly_ntz" id="boxofficeHelpLayerWide" style="display:none;">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
# 						영화진흥위원회 영화관 입장권 통합전산망 제공
# 						<button class="btn_close" id="boxofficeHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </span>
# </span><span class="count">3,651,787명<em>(04.30 기준)</em></span>
# </p>
# <div class="info_spec2">
# <dl class="step1">
# <dt>감독</dt>
# <dd>
# <a href="/movie/bi/pi/basic.nhn?code=37393">신카이 마코토</a>
# </dd>
# </dl>
# <dl class="step2">
# <dt>출연</dt>
# <dd>
# <a href="/movie/bi/pi/basic.nhn?code=70295">카미키 류노스케<span>(타키 목소리)</span></a>,
#
#
#
#
#
#
#
#
#
# 									<a href="/movie/bi/pi/basic.nhn?code=335287">카미시라이시 모네<span>(미츠하 목소리)</span></a>
# </dd>
# </dl>
# <a class="more" href="./detail.nhn?code=150198" title="더보기">더보기</a>
# </div>
# <div class="end_btn_area">
# <ul>
# <li><a class="btn_rsv _reserveHelpWide" href="/movie/bi/mi/reserve.nhn?code=150198" id="reserveWide" title="예매하기"><em>예매하기</em></a>
# <div class="ly_mileage _reserveHelpWide" id="reserveHelpWide" style="display:none">
# <span></span>영화관람후 평점을 작성하시면 <em>네이버페이 포인트 500원</em>을 드립니다! <a class="btn_close _reserveHelpWide" href="#" id="reserveHelpWideCloseButton"><em>닫기</em></a>
# </div>
# </li>
# <li><a class="btn_original" href="http://book.naver.com/bookdb/book_detail.nhn?bid=11463103" target="_blank" title="원작 도서"><em>원작 도서</em></a><!-- N=a:ifo.book --></li>
# <li>
# <!-- [D]btn_site_on 으로 컨트롤 -->
# <a class="btn_site" href="javascript:displayMovieHomepageLayerW();" id="movieHomePageButtonW" title="공식사이트"><em>공식사이트</em></a> <!-- 공식 사이트 레이어 -->
# <div class="ly_site" id="movieHomePageLayerW" style="display: none">
# <p><a href="http://your-name.kr" target="_blank" title="해당 URL로 가기">http://your-name.kr</a></p>
# <a class="btn_close" href="javascript:hideMovieHomepageLayerW();"><em>닫기</em></a>
# </div> <!-- //공식 사이트 레이어 -->
# </li>
# <li>
# <div class="u_likeit_module"></div>
# </li>
# </ul>
# </div>
# <div class="spi_area">
# <div class="naver-splugin" data-me-display="off" data-oninitialize="movie_oninitialize()" data-style="standard-v1-text" id="wideSpiLayer"></div>
# </div>
# </div>
# </div>
# <!-- //영화정보(wide) -->
# <!-- 영화정보(basic) -->
# <div class="mv_info_area">
# <div class="mv_info">
# <h3 class="h_movie">
# <a href="./basic.nhn?code=150198">너의 이름은.</a><!-- N=a:ifo.title --> <a class="opening" href="/movie/running/current.nhn?order=reserve"><em>상영중</em></a><!-- N=a:ifo.nbtn --></h3>
# <strong class="h_movie2" title="君の名は。, your name., 2016">君の名は。, your name., 2016</strong>
# <div class="main_score">
# <div class="score">
# <div class="uio_ntz_btn see">
# <span class="ntz _actualPointHelpBasic">
# <em class="blind">관람객 평점</em>
# <a class="help _actualPointHelpBasic" href="#" id="actualPointHelpButtonBasic">관람객 평점 도움말</a>
# </span>
# <div class="ly_ntz" id="actualPointHelpBasic" style="display:none" z-index="20">
# <span></span>
# 							관람객 평점은 네이버영화에서<br>예매하고 실제 관람 후 이용자들이<br>작성한 평점입니다.
# 							<button class="btn_close _actualPointHelpBasic" id="actualPointHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </br></br></div>
# <div class="ly_count" id="actualPointCountBasic" style="display:none">
# <span></span>
# 							참여 <em>10,839</em>명
# 						</div>
# </div>
# <a class="ntz_score" href="./point.nhn?code=150198&amp;onlyActualPointYn=Y#pointAfterTab" id="actualPointPersentBasic">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.2%">관람객 평점 9.02점</span></span><em class="num9">9</em><em class="dot">.</em><em class="num0">0</em><em class="num2">2</em>
# </div>
# </a><!-- N=a:ifo.mgrating -->
# </div>
# <div class="score">
# <div class="spc_score_area">
# <a class="spc" href="./point.nhn?code=150198#pointExpertTab">
# <span class="spc_score"><em class="blind">기자 · 평론가 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:71.7%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num1">1</em><em class="num7">7</em>
# </div>
# </a><!-- N=a:ifo.crating -->
# </div>
# </div>
# <div class="score score_left">
# <div class="uio_ntz_btn">
# <span class="ntz">
# <em class="blind">네티즌 평점</em><a class="help" href="#" id="pointHelpButtonBasic" title="네티즌 평점 도움말 보기">네티즌 평점 도움말</a>
# </span>
# <div class="ly_ntz" id="pointHelpBasic" style="display:none" z-index="20">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
#
#
#
# 								국내 개봉작입니다. 관람하신 영화에 대한<br> 평점을 남겨주세요. 140자평 뿐 아니라 블<br>로그 영화 리뷰작성 시 등록한 별점도 함께<br> 반영됩니다.
#
#
# 						<button class="btn_close" id="pointHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </br></br></br></div>
# <div class="ly_count" id="pointNetizenCountBasic" style="display:none">
# <span></span>
# 						참여 <em>28,379</em>명
# 					</div>
# </div>
# <div class="star_score ">
# <a href="./point.nhn?code=150198#pointAfterTab" id="pointNetizenPersentBasic"><span class="st_off"><span class="st_on" style="width:88.1%"></span></span><em class="num8">8</em><em class="dot">.</em><em class="num8">8</em><em class="num1">1</em></a><!-- N=a:ifo.arating -->
# </div>
# </div>
# <div class="score" id="noPoint">
# <div class="my_score_area">
# <!--[D] 내평점이 없는경우 화살표를 없애기 위해 class="my"가 빠진다 -->
# <a href="./point.nhn?code=150198#pointAfterTab">
# <span class="my_score"><em class="blind">내 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:0%">0점</span></span>
# <span class="btn_write">등록</span>
# </div>
# </a>
# </div>
# </div>
# <div class="score" id="existPoint" style="display : none">
# <div class="my_score_area">
# <a class="my" href="javascript:pointBasic.toggleMyPoint();">
# <span class="my_score">
# <em class="blind">내 평점</em>
# </span>
# <div class="star_score" id="starPoint">
# <span class="st_off"><span class="st_on" id="pointStar" style="width:0%"></span></span>
# </div>
# </a><!-- N=a:ifo.marating -->
# <div class="ly_my" id="myPointLayerBasic" style="display:none">
# <span id="pointText"></span><a class="btn_del" href="javascript:checkAlreadyPointAfterExist('basic', );" id="pointRemove">삭제</a>
# <a class="btn_close" href="javascript:pointBasic.toggleMyPoint();"><em>닫기</em></a>
# </div>
# </div>
# </div>
# </div>
# <dl class="info_spec">
# <dt class="step1"><em>개요()</em></dt>
# <dd>
# <p>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:ifo.genre -->,
#
#
#
# 					<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:ifo.genre -->,
#
#
#
# 					<a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:ifo.genre -->
# </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?nation=JP">일본</a><!-- N=a:ifo.nation -->
# </span>
# <span>106분 </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=2017"> 2017</a><!-- N=a:ifo.year -->
# <a href="/movie/sdb/browsing/bmovie.nhn?open=20170104">.01.04</a><!-- N=a:ifo.day --> 개봉
#
#
#
# 					</span>
# </p>
# </dd>
# <dt class="step2"><em>감독</em></dt>
# <dd><p><a href="/movie/bi/pi/basic.nhn?code=37393">신카이 마코토</a><!-- N=a:ifo.director --></p></dd>
# <dt class="step3"><em>출연</em></dt>
# <dd><p><a href="/movie/bi/pi/basic.nhn?code=70295">카미키 류노스케</a><!-- N=a:ifo.actor -->(타키 목소리), <a href="/movie/bi/pi/basic.nhn?code=335287">카미시라이시 모네</a><!-- N=a:ifo.actor -->(미츠하 목소리)</p><a class="more" href="detail.nhn?code=150198" title="더보기">더보기</a><!-- N=a:ifo.actmore --></dd>
# <dt class="step4"><em>등급</em></dt>
# <dd>
# <p>
# 						[국내]
#
# 							<a href="/movie/sdb/browsing/bmovie.nhn?grade=1001002">12세 관람가</a><!-- N=a:ifo.filmrate -->
# </p>
# </dd>
# <dt class="step9"><em>흥행</em></dt>
# <dd>
# <div class="step9_cont">
# <div class="uio_ntz_btn">
# <span class="ntz">누적관객<a class="help" href="#" id="boxofficeHelpButtonBasic" title="누적관객 도움말 보기">누적관객 도움말</a></span>
# <div class="ly_ntz" id="boxofficeHelpLayerBasic" style="display:none;">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
# 									영화진흥위원회 영화관 입장권 통합전산망 제공
# 									<button class="btn_close" id="boxofficeHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </div>
# </div>
# <p class="count">3,651,787명<span>(04.30 기준)</span></p>
# </div>
# </dd>
# </dl>
# <!-- [D] 개봉전 : 기대지수 -->
# <!-- //개봉전 : 기대지수 -->
# <ul class="photo_video">
# <li><a href="photoView.nhn?code=150198&amp;imageNid=6534953#tab">
# <img alt="너의 이름은." height="40" onerror="this.src='http://static.naver.net/movie/2012/06/dft_img50x33.png'" src="http://movie2.phinf.naver.net/20160927_20/1474960029918woJpk_JPEG/movie_image.jpg?type=n53_40_2" width="53"/>
# </a><!-- N=a:ifo.photo --></li>
# <li><a href="photoView.nhn?code=150198&amp;imageNid=6534954#tab">
# <img alt="너의 이름은." height="40" onerror="this.src='http://static.naver.net/movie/2012/06/dft_img50x33.png'" src="http://movie2.phinf.naver.net/20160927_265/1474960030088VIdg2_PNG/movie_image.jpg?type=n53_40_2" width="53"/>
# </a><!-- N=a:ifo.photo --></li>
# <li><a href="photoView.nhn?code=150198&amp;imageNid=6534955#tab">
# <img alt="너의 이름은." height="40" onerror="this.src='http://static.naver.net/movie/2012/06/dft_img50x33.png'" src="http://movie2.phinf.naver.net/20160927_195/1474960030235ot3Ih_JPEG/movie_image.jpg?type=n53_40_2" width="53"/>
# </a><!-- N=a:ifo.photo --></li>
# <li><a href="mediaView.nhn?code=150198&amp;mid=33017#tab">
# <span class="vtr">영상</span> <img alt="너의 이름은." height="40" onerror="this.src='http://static.naver.net/movie/2012/06/dft_img50x33.png'" src="http://imgmovie.naver.net/multimedia/MOVIECLIP/TRAILER/33017_20161213051921.jpg" width="53"/>
# </a><!-- N=a:ifo.video --></li>
# <li><a href="mediaView.nhn?code=150198&amp;mid=32993#tab">
# <span class="vtr">영상</span> <img alt="너의 이름은." height="40" onerror="this.src='http://static.naver.net/movie/2012/06/dft_img50x33.png'" src="http://imgmovie.naver.net/multimedia/MOVIECLIP/TRAILER/32993_20161212031549.gif" width="53"/>
# </a><!-- N=a:ifo.video --></li>
# <li><a href="mediaView.nhn?code=150198&amp;mid=32910#tab">
# <span class="vtr">영상</span> <img alt="너의 이름은." height="40" onerror="this.src='http://static.naver.net/movie/2012/06/dft_img50x33.png'" src="http://imgmovie.naver.net/multimedia/MOVIECLIP/TRAILER/32910_20161205112401.png" width="53"/>
# </a><!-- N=a:ifo.video --></li>
# </ul>
# <div class="btn_sns">
# <div class="end_btn_area">
# <ul>
# <li><a class="btn_rsv _reserveHelpBasic" href="/movie/bi/mi/reserve.nhn?code=150198" id="reserveBasic" title="예매하기"><em>예매하기</em></a><!-- N=a:ifo.ticket -->
# <div class="ly_mileage _reserveHelpBasic" id="reserveHelpBasic" style="display:none">
# <span></span>영화관람후 평점을 작성하시면 <em>네이버페이 포인트 500원</em>을 드립니다! <a class="btn_close _reserveHelpBasic" href="#" id="reserveHelpBasicCloseButton"><em>닫기</em></a>
# </div>
# </li>
# ...
# 			if (true) {
# 				deleteApiUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(deleteApiUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return;
# 			}
#
# 			top.location.reload(true);
# 		}
# };
#
# function toggleDropBox(id) {
# 	wel = jindo.$Element(id);
# 	if (wel) {
# 		wel.toggle();
# 	}
# }
#
# var reviewWriteUrl = "http://" + location.hostname + "/movie/bi/mi/reviewwrite.nhn?code=150198&from=basic#tab";
#
# function checkLoginNgoReivewWrite() {
# 	if(false == false){
# 		if(confirm("로그인이 필요합니다. 로그인 하시겠습니까?")){
# 			location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(reviewWriteUrl);
# 		}
# 		return false;
# 	}
# 	return true;
# }
#
# function goWrite() {
# 	if(checkLoginNgoReivewWrite() == false) {
# 		return;
# 	} else {
# 		location.href = reviewWriteUrl;
# 	}
# }
#
#
# function reservation(mcode, mtype, gcode, tcode, date, time, bOutLink) {
# 	var url = "/movie/reservation/index.nhn?";
# 	var param = "rmcode=" + mcode + "_" + mtype;
# 	param = param + "&gcode=" + gcode;
# 	param = param + "&tcode=" + tcode;
# 	param = param + "&date=" + date;
# 	param = param + "&time=" + time;
#
#
# 	if (bOutLink) {
# 		window.open(url + param);
# 	} else {
# 		location.href = url + param;
# 	}
# }
#
# function showPointListByNid(nid){
#
#
#
# 		location.href = "http://" + location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
#
#
#
# }
#
# jindo.$Fn(function() {
#
# 		var elMakingnotePhase = jindo.$Element('makingnotePhase');
#
# 		if (elMakingnotePhase.height() == elMakingnotePhaseHeight) {
# 			elMakingnotePhase.className("con_tx");
# 			makingnotePhaseClassName = "con_tx";
# 		} else if (elMakingnotePhase.height() > elMakingnotePhaseHeight) {
# 			elMakingnotePhase.height(630);
# 			elMakingnotePhase.className("con_tx");
# 			makingnotePhaseClassName = "con_tx";
# 		}
#
#
# 	if (jindo.$('reviewHelpButton') != null) {
# 		new jindo.LayerManager("reviewHelp", {
# 		    sCheckEvent : "click",
# 		    nHideDelay : 0
# 		}).link(jindo.$("reviewHelp"), jindo.$("reviewHelpButton"));
#
# 		jindo.$Element("reviewHelpButton").attach("click", function(e){
# 		    e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		    jindo.$Element("reviewHelp").toggle();
# 		});
# 	}
#
#   if (27569 > 0 || 28,379 > 0) {
# 	  if (jindo.$("bestPointHelp") != null) {
# 		  new jindo.LayerManager("bestPointHelp", {
# 		      sCheckEvent : "click",
# 		      nHideDelay : 0
# 		  }).link(jindo.$("bestPointHelp"), jindo.$("bestPointHelpButton"));
#
# 		  jindo.$Element("bestPointHelpButton").attach("click", function(e){
# 		      e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		      jindo.$Element("bestPointHelp").toggle();
# 		  });
#
# 		  jindo.$Element("bestPointHelpCloseButton").attach("click", function(e){
# 				e.stop(jindo.$Event.CANCEL_DEFAULT);
# 				jindo.$Element("bestPointHelp").hide();
# 		  });
# 	  }
#   }
#
# }).attach(document, "domready");
#
# if(false == true) {
# 	if(jindo.$Element("btn_interest_basic") != null && jindo.$Element("btn_notInterest_basic") != null) {
# 		jindo.$Element("btn_interest_basic").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			queryAndUpdatePreference('150198','interest');
# 		});
#
# 		jindo.$Element("btn_notInterest_basic").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			queryAndUpdatePreference('150198','notInterest');
# 		});
# 	}
# }
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("150198", "after");
# </script>
# <!-- //content -->
# </div>
# <!-- //container -->
# <!-- footer -->
# <div id="footer">
# <div class="in_footer">
# <div class="foot_con">
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" target="rules"><strong>이용약관</strong></a><!-- N=a:fot.agreement --></li>
# <li><a href="http://www.naver.com/rules/privacy.html" target="rules"><strong>개인정보처리방침</strong></a><!-- N=a:fot.privacy --></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" target="rules"><strong>책임의 한계와 법적고지</strong></a><!-- N=a:fot.disclaimer --></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=800" target="customer"><strong>영화 고객센터</strong></a><!-- N=a:fot.help --></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <p class="info">
# 					사업자등록번호 : 220-81-62517<span>통신판매업 신고번호</span> : 경기성남 제 2006 - 692호<span>대표이사 : 한성숙</span><span><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp">사업자등록정보 확인</a><!-- N=a:fot.bizinfo --></span><br>
# 					주소 : 경기도 성남시 분당구 불정로 6 네이버 그린팩토리 <span>대표전화 : 1588-3820</span>
# </br></p>
# <address>
# <a class="logo" href="http://www.navercorp.com/" target="_blank"><img alt="NAVER" height="11" src="http://static.naver.net/movie/2013/07/logo_naver.png" width="63"/></a><!-- N=a:fot.nhn -->
# <em>Copyright ©</em>
# <a href="http://www.navercorp.com/" target="_blank">NAVER Corp.</a><!-- N=a:fot.corp -->
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# if (false) {
# 	var alertType = "NONE";
# 	var koreanTitle = "";
# 	var movieCode = "0";
# 	var userReserveCount = "0";
# 	var todayDatetime = "20170501212150";
# 	var endDatetimeAfterTwoDays = "00000000000000";
#
#
# 	if (movieCode > 0) {
# 		openWriteActualPointAlert (alertType, koreanTitle, movieCode, userReserveCount, todayDatetime, endDatetimeAfterTwoDays);
# 	}
# }
#
# function openWriteActualPointAlert (alertType, koreanTitle, movieCode, count, today, endDate) {
# 	if (alertType == "ONE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 " + koreanTitle + "에\n평점 등록 시 네이버페이 포인트 500원 적립!\n지금 평점쓰기 메뉴로 이동하시겠습니까?")) {
# 			top.location.href = "http://movie.naver.com/movie/bi/mi/point.nhn?code=" + movieCode;
# 		}
# 	} else if (alertType == "MORE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 작품에 평점을 등록해주세요\n작품당 네이버페이 포인트 500원씩 적립!\n평점 미등록작 리스트를 확인하시겠습니까?")) {
# 			top.location.href = "http://ticket.movie.naver.com/Order/OverdueList.aspx";
# 		}
# 	}
# }
#
# function setCookieLastUserReserveDate(today, endDate) {
# 	var cookieForNotOpenActualPointPopup = jindo.$Cookie();
#
#
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveDatetime");
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveCheckDatetime");
#
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveDatetime", endDate, 9999, "movie.naver.com");
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveCheckDatetime", today, 9999, "movie.naver.com");
# }
#
# </script>
# <script type="text/javascript">
#
#
#
#
# 			var alertMessage = "지원되지 않는 브라우저로 서비스 이용에 제한이 있습니다.";
#
#
#
# 	function getBrowser() {
# 		var ua = navigator.userAgent;
# 		if (/NAVER/.test(ua)) {
# 			return "NAVER_APP";
# 		} else if (/IEMobile/.test(ua)) {
# 			return "INTERNET_EXPLORER_MOBILE";
# 		} else if (/MSIE/.test(ua) || /Trident/.test(ua)) {
# 			return "INTERNET_EXPLORER";
# 		} else if (/Firefox/.test(ua)) {
# 			return "FIREFOX";
# 		} else if (/Opera\//.test(ua) || /OPR\//.test(ua)) {
# 			return "OPERA";
# 		}  else if (/Swing\//.test(ua)) {
# 			return "SWING";
# 		} else if (/Chrome\//.test(ua) || /CriOS\//.test(ua)) {
# 			return "CHROME";
# 		} else if (/BAND\//.test(ua)) {
# 			return "BAND_APP";
# 		} else if (/FBAN\/FBIOS/.test(ua)) {
# 			return "FACEBOOK_APP";
# 		} else if (/Twitter/.test(ua)) {
# 			return "TWITTER_APP";
# 		} else if (/KAKAOTALK/.test(ua)) {
# 			return "KAKAOTALK_APP";
# 		} else if (/Android/.test(ua) && /Safari/.test(ua)) {
# 			return "ANDROID_INTERNET_APP";
# 		} else if (/Safari/.test(ua)) {
# 			return "SAFARI";
# 		}
#
# 		return "";
# 	}
#
# 	if (getBrowser() === "UNKNOWN" && jindo.$Cookie().get("notSupportBrowserAlert") != 'true') {
# 		alert(alertMessage);
# 		jindo.$Cookie().set("notSupportBrowserAlert", "true", "9999", "movie.naver.com");
# 	}
#
#
# </script>
# <!-- //footer -->
# </div>
# <script type="text/javascript">
# var isRecentTab = false;
#
# jindo.$Fn(function (we) {
#
# 	    // 윈도우창 리사이징에 따른 레이아웃 1/2단 관리
# 	    var oViewMode = new nhn.movie.end.ViewMode();
#
#
# 	// 상단 검색영역
# 	var oSearch = new nhn.movie.Search({
# 		area : "jSearchArea",
# 		autosearch : "http://auto.movie.naver.com/ac?q_enc=UTF-8&st=1&r_lt=1&n_ext=1&t_koreng=1&r_format=json&r_enc=UTF-8&r_unicode=0&r_escape=1&q=",
# 		movelink : "/movie/bi/mi/basic.nhn?code=",
# 		peoplelink : "/movie/bi/pi/basic.nhn?code="
# 	});
#
#     // 좌측 LNB
#     var oLNB = new nhn.movie.LNB();
# 	if( typeof oViewMode != "undefined") {
# 		oViewMode.attach('change', jindo.$Fn(oLNB.update, oLNB).bind());
# 	}
#
#     // 2단일때, 2열에 상단 회색 라인 없애기
# 	if( typeof oViewMode != "undefined") {
# 	    oViewMode.attach('change', function (oEvent) {
# 	        var welSecondSectionGroup = jindo.$Element('content').queryAll('.section_group')[1];
# 	        var wel2column1rowSection;
#
# 	        if (welSecondSectionGroup) {
# 	            wel2column1rowSection = welSecondSectionGroup.query('.obj_section');
#
# 	            if (oEvent.sStyle == 'wide') {
# 	                wel2column1rowSection.addClass('noline');
# 	            } else {
# 	                wel2column1rowSection.removeClass('noline');
# 	            }
# 	        }
#
# 		    //포토 묻어가기
# 		    if( typeof oPhoto != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oPhoto.setWide("wide");
# 			    } else {
# 				    oPhoto.setWide("basic");
# 			    }
# 		    }
# 		    // 비디오 묻어가기
# 		    if( typeof oMovie != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oMovie.setWide("wide", 1);
# 			    } else {
# 				    oMovie.setWide("basic", 1);
# 			    }
# 		    }
#
# 	    });
# 	}
#
#     // 상단썸네일영역
#
#
# 		var welTopArea = jindo.$Element('_TopArea');
# 		new nhn.movie.end.TopAreaThumbnailExpander(welTopArea.query('.current_mv_list .top_poster_area')).attach({
# 		    click: function (oEvent) {
# 		        clickcr(oEvent.element, 'rnk.nimg', '', '', event);
# 		    }
# 		});
# 		new nhn.movie.end.TopAreaThumbnailExpander(welTopArea.query('.expected_mv_list .top_poster_area')).attach({
# 		    click: function (oEvent) {
# 		        clickcr(oEvent.element, 'rnk.simg', '', '', event);
# 		    }
# 		});
# 		var oTopAreaManager = new nhn.movie.end.movie.TopAreaManager(welTopArea);
# 		if ( typeof oViewMode == "undefined" || oViewMode.is('basic') ) {
# 		    oTopAreaManager.enableNavigationBtns();
# 		} else {
# 		    oTopAreaManager.disableNavigationBtns();
# 		}
# 		if( typeof oViewMode != "undefined" ) {
# 			var tempEvent = {};
# 			oViewMode.attach('change', jindo.$Fn(oTopAreaManager.onViewModeChange, oTopAreaManager).bind());
#
# 		    if (oViewMode.is('basic') && oViewMode.serverSstyle != 'basic') {
# 		    	tempEvent.sStyle = 'basic';
# 			    oTopAreaManager.onViewModeChange(tempEvent);
# 		    } else if (oViewMode.is('wide') && oViewMode.serverSstyle != 'wide') {
# 		    	tempEvent.sStyle = 'wide';
# 			    oTopAreaManager.onViewModeChange(tempEvent);
# 		    }
# 		}
#
#
#
#
#     var waelScriptOrderList = jindo.$ElementList('._gnb_another_service_layer');
#
#     jindo.$A(waelScriptOrderList.$value()).forEach(function(value, index, array) {
# 		jindo.$Fn(reviewOrderLayerToggle, this).attach(value, "blur");
# 	});
#     //자동닫힘 기능 끝.
#
#   //영화검색 결과에서 포커스 아웃될 경우, 검색 결과를 지우도록 변경.
#     jindo.$Element("lnb_gonaver").attach("focus",function(e){
#
#     	jindo.$Element('search_placeholder').attr({
#     		"style" : "display: inline;"
#     	})
#     	jindo.$Element('ipt_tx_srch').$value().value="";
#
#     	if(jindo.$Element("jAutoComplate") != null){
#     		jindo.$Element("jAutoComplate").hide();
#     	}
#     });
#
#
#     /**
#      * 영화 END 페이지
#      */
#     var welMovieInfoWideArea = jindo.$Element(jindo.$$.getSingle('.wide_info_area'));
#     var welMovieInfoBasicArea = jindo.$Element(jindo.$$.getSingle('.mv_info_area'));
#     if ( oViewMode.is('basic') ) {
#         welMovieInfoWideArea.hide();
#         welMovieInfoBasicArea.show();
#     } else {
#         welMovieInfoBasicArea.hide();
#         welMovieInfoWideArea.show();
#     }
#     oViewMode.attach('change', function (oEvent) {
#         // 기본정보 영역 변경
#         if ( oEvent.sStyle === 'basic' ) {
#             welMovieInfoWideArea.hide();
#             welMovieInfoBasicArea.show();
#         } else {
#             welMovieInfoBasicArea.hide();
#             welMovieInfoWideArea.show();
#         }
#     });
#
#
#
#         /* 영화주요정보 탭 */
#
#         // 포토영역
#         new nhn.movie.end.MainPhotoArea(
#             jindo.$('_MainPhotoArea'), // Element
#             '/movie/bi/mi/photoListJson.nhn?movieCode=150198', // List API URL
#             {
#             	"lists":[
#
#             			{"nid":0,"imageNid":6534953,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063b729","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20160927_20/1474960029918woJpk_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6534954,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063b72a","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20160927_265/1474960030088VIdg2_PNG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6534955,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063b72b","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20160927_195/1474960030235ot3Ih_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6541754,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063d1ba","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20161116_187/14792642146572PCVC_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6541755,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063d1bb","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20161116_232/1479264214874iLNKP_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6541756,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063d1bc","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20161116_30/1479264215047b4Krx_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6541757,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063d1bd","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20161116_81/1479264215287Tkk8P_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6541758,"imageType":"STILLCUT","movieCode":150198,"gdid":"080005ea_00000063d1be","adult":false,"fullImageUrl427px":"http://movie.phinf.naver.net/20161116_207/1479264215441xOsgI_JPEG/movie_image.jpg?type=m427_320_2"}
#
#             	]
#             }, // First List Object
#             jindo.$('mainPhotoViewIndex')
#         ).attach('updated', function (oEvent) {
#             var sRnd = (new Date()).getTime();
#             var sb = [];
#             var _displayNIndex = eval(oEvent.nIndex) + 1;
#
#             // 현재 포토 위치
#             jindo.$Element('mainPhotoViewIndex').text(_displayNIndex);
#
#             // 포토 조회수
#             new jindo.$Ajax('/movie/bi/mi/photoViewCount.nhn?imageNid=' + oEvent.imageNid, {
#                 method : 'get',
#                 onload : function(res){}
#             }).request();
#
#             // NDS
#             try {
#                 lcs_do();
#             } catch(e){}
#
#             // 코리안클릭 PV집계
# 			sb.push('<iframe height="0" frameborder="0" width="0" scrolling="no" src="');
# 			sb.push('/movie/bi/mi/photoViewCountDummy.nhn?_timestamp=' + sRnd);
# 			sb.push('"></iframe>');
# 			var sHtml = sb.join("");
# 			var elContent = jindo.$Element("footer");
# 			elContent.appendHTML(sHtml);
#         });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     /**
#      * 기타 공통
#      */
#
#     // LCS
# 	try{ lcs_do(); } catch(e){}
# }).attach(document, 'domready');
# </script>
# <script type="text/javascript">
# 	//nClick 초기화 영역
# 	//클릭로그 집계 코드 추가
# 	var ccsrv="cc.naver.com";
# 	var nclk_evt = 1;
#
# 	nclk_do();
# 	//nClick 초기화 영역 끝
# </script>
# </body>
# </html>

# %%
origin_title = data.select('div[class=mv_info] strong[class=h_movie2]')
origin_title
# Out:
# [<strong class="h_movie2" title="君の名は。									, your name.										, 					2016">君の名は。
#
#  					, your name.
#
#  					,
#  					2016</strong>,
#  <strong class="h_movie2" title="君の名は。, your name., 2016">君の名は。, your name., 2016</strong>]

# %%
origin_title[0].text
# Out:
# '君の名は。\r\n\t\t\t\t\r\n\t\t\t\t\t, your name.\r\n\t\t\t\t\t\r\n\t\t\t\t\t, \r\n\t\t\t\t\t2016'

# %%
origin_title[0].text.replace("\t", '').replace('\r', '').replace('\n', '')
# Out:
# '君の名は。, your name., 2016'

# %%
kor_title = data.select('div[class=mv_info] h3[class=h_movie] a')
kor_title[0].text
# Out:
# '너의 이름은.'

# %% [markdown]
# ## try - exception practice

# %% [raw]
# for i in range(5):
#     try:
#         s = str(i) if i != 3 else 'a%d' % i
#         j = int(s)
#
#         print('s = %s, j = %d' % (s, j))
#     except Exception as e:
#         print(e)
#         continue

# %% [markdown]
# # Scraping

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

def get_soup(url):
    try:
        r = requests.get(url, headers=headers).text
        return BeautifulSoup(r, 'lxml')
    except Exception as e:
        exc_type, exc_value, exc_traceback = sys.exc_info()
        traceback_details = {
                     'filename': exc_traceback.tb_frame.f_code.co_filename,
                     'lineno'  : exc_traceback.tb_lineno,
                     'name'    : exc_traceback.tb_frame.f_code.co_name,
                     'type'    : exc_type.__name__,
                     'message' : str(e)
                    }
        pprint(traceback_details)
        return ''

# Basic pages
def get_basic_page(movie_id):
    url = url_basic_base % movie_id
    return get_soup(url)

def parse_basic_page(page):
    movie = {}

    score = _parse_main_score(page)
    movie['expert_score'] = score[0]
    movie['netizen_score'] = score[1]

    movie['title'] = _parse_title(page)
    movie['e_title'] = _parse_e_title(page)

    try:
        basic_inf = page.select('dl[class=info_spec]')[0]
        movie['genres'] = _parse_genres(page)
        movie['countries'] = _parse_countries(page)
        movie['running_time'] = _parse_running_time(page)
        movie['open_dates'] = _parse_open_date(page)
        movie['grade'] = _parse_grade(page)
        return movie
    except Exception as e:
        exc_type, exc_value, exc_traceback = sys.exc_info()
        traceback_details = {
                     'filename': exc_traceback.tb_frame.f_code.co_filename,
                     'lineno'  : exc_traceback.tb_lineno,
                     'name'    : exc_traceback.tb_frame.f_code.co_name,
                     'type'    : exc_type.__name__,
                     'message' : str(e)
                    }
        return movie
    
def _parse_title(page):
    try: 
        return page.select('div[class=mv_info] h3[class=h_movie] a')[0].text.strip()
    except:
        return ''

def _parse_e_title(page):
    try:
        return page.select('div[class=mv_info] strong[class=h_movie2]')[0].text.replace('\r', '').replace('\t', '').replace('\n', '').strip()
    except:
        return ''

def _parse_genres(page):
    genres = page.select('a[href^=/movie/sdb/browsing/bmovie.nhn?genre=]')
    return list({genre.text for genre in genres})
    
def _parse_countries(page):
    countries = page.select('a[href^=/movie/sdb/browsing/bmovie.nhn?nation=]')
    return list({country.text for country in countries})
    
def _parse_running_time(page):
    running_time = 0
    try:
        running_time = re.search(r"\d+분", page.text).group()[:-1]
    except:
        running_time = 0
    return running_time

def _parse_open_date(page):
    return list({d for d in re.findall(r"\d+\.\d+\.\d+ 재*개봉", page.text)})

def _parse_grade(page):
    try:
        return page.select('a[href^=/movie/sdb/browsing/bmovie.nhn?grade]')[0].text
    except:
        return ''

def _parse_main_score(page):
    try:
        main_score = page.select('div[class=main_score]')[0]
        expert_score = main_score.select('div[class=spc_score_area] div[class=star_score]')[0].text.replace('\n','')
        netizen_score = main_score.select('div[class=score] div[class=star_score] span[class=st_off]')[0].text.replace('관람객 평점 ', '').replace('점', '')
        return expert_score, netizen_score
    except Exception as e:
        # print('error from _parse_main_score', e)
        return -1, -1

# def _parse_poster(page):
#     try:
#         return page.select('img[class=_Img]')[0]
#     except:
#         return ''

# %% [markdown]
# # scraping TIPS

# %% [markdown]
# ### 1. time.sleep

# %%
for movie_id in range(134960, 134965):
    url = url_basic_base % movie_id
    page = get_soup(url)
    title = _parse_title(page)
    print('%d: %s' % (movie_id, title))
    time.sleep(1.0) # 1초 기다리기
# Out:
# 134960: 그놈이다
# 134961: 어 라 말라
# 134962: 아이
# 134963: 라라랜드
# 134964: 콜 포 헬프

# %% [markdown]
# ### 2. User agent

# %% [markdown]
# headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
#
# response = requests.get(url, headers=headers)
#
# http://www.useragentstring.com/pages/useragentstring.php?name=Chrome

# %% [markdown]
# ### 3. file download

# %% [markdown]
# 파이썬에서도 음악/사진 파일들을 다운로드 받을 수 있습니다. 다운로드라는 것도 서버와 내 컴퓨터 간의 통로를 열어두고, 전송이 되는 byte 정보들을 모아서 다시 음악, 사진 포멧으로 읽는 것입니다. 물론 스트리밍 서비스들은 temporal하게 내 컴퓨터에 데이터가 쌓이지 않게 막을 수도 있습니다. 그런 종류가 아니라, \<a>라는 태그로 링크가 걸려있는 이미지 파일들을 다운로드 해보겠습니다.
#
# 아래 코드는 urllib.request.urlopen을 통하여 서버와 내 컴퓨터 간의 통신 통로를 열어둡니다. while loop 안에서 열려진 통로에서 100000000 byte만큼의 정보를 가져와 buffer에 넣습니다. 그리고 이 정보를 미리 열어둔 downloaded_file이라는 파일에 적습니다. 주고 받은 정보가 텍스트가 아니라 바이트이기 때문에 'wb'로 파일을 열어둡니다. 다운로드가 모두 끝나면 열어둔 통신 서버를 닫고
#
#     opened.close()
#
# 열어둔 파일도 닫습니다.
#
#     downloaded_file.close()
#
# 다운로드가 성공적으로 되었다면 True가, 실패했다면 False가 return 되도록 try - except로 이 코드 부분을 감싸줍니다

# %%
import urllib

def download_file(url, fname):
    try:
        downloaded_file = open(fname, "wb")
        opened = urllib.request.urlopen(url)
        while True:
            buffer = opened.read(100000000)
            if len(buffer) == 0:
                break
            downloaded_file.write(buffer)
        opened.close()
        downloaded_file.close()
        return True
    except:
        return False

# %%
movie_img_url = page.select('img[class=_Img]')
movie_img_url
# Out:
# [<img alt="POSTER" class="_Img" src="http://movie.phinf.naver.net/20150123_72/14220061096862xbEP_JPEG/movie_image.jpg?type=m427_320_2"/>]

# %%
download_file('http://movie.phinf.naver.net/20161125_80/1480051484421z6wDD_JPEG/movie_image.jpg', 'movie_image.jpg')
# Out:
# True

# %%
# %ls
# Out:
# 1_data_file_json.ipynb                google_logo.png
# 2_pos_tag_with_konlpy.ipynb           movie_image.jpg
# 3_scraping_naver_movie.ipynb          movie_image.png
# 5_Keyword_extraction.ipynb            mypy/
# 6_corpus_class.ipynb                  soy/
# README.md                             word-movers-distance-in-python.ipynb
# WMD.pdf                               강의자료/
# data/
