# %%
import sys
sys.path.append('./soy/')
import soy


TRAIN_COHESION = True
TOKENIZE = True

corpus_fname = './data/sample_naver_movie/merged_comments.txt'
tokenized_corpus_fname = './data/sample_naver_movie/merged_comments_tokenized.txt'
cohesion_fname = './data/sample_naver_movie/navermovie_cohesion'
maxscore_fname = './data/sample_naver_movie/navermovie_maxscore.pkl'


TRAIN_DOC2VEC = True
doc2vec_fname = './data/sample_naver_movie/movie_review_doc2vec_model.pkl'

id2movie_fname = './data/sample_naver_movie/navermovie_info_idx2moviename.pkl'
id2actor_fname = './data/sample_naver_movie/navermovie_info_idx2actorname.pkl'

# %% [markdown]
# ## Doc2vec

# %% [markdown]
# Doc2Vec을 학습하기 위해서는 각각 문서의 label이 저장되어야 합니다. 이를 위하여 TaggedDocument라는 클래스가 이용됩니다. TaggedDocument는 단어들을 words에, 레이블 정보를 tags에 리스트 형태로 입력합니다

# %%
import os
import pickle
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument


class CommentDoc2Vec:
    
    def __init__(self, fname):
        self.fname = fname
        if not os.path.isfile(fname):
            print('File not found: %s' % fname)
        
    def __iter__(self):
        with open(self.fname, encoding='utf-8') as f:
            for doc in f:
                movie_idx, text, score = doc.split('\t')
                yield TaggedDocument(words=text.split(), tags=['MOVIE_%s' % movie_idx])

                
doc2vec_corpus = CommentDoc2Vec(tokenized_corpus_fname)


if TRAIN_DOC2VEC:
    doc2vec_model = Doc2Vec(doc2vec_corpus)
    with open(doc2vec_fname, 'wb') as f:
        pickle.dump(doc2vec_model, f)

else:
    with open(doc2vec_fname, 'rb') as f:
        doc2vec_model = pickle.load(f)

# %%
doc2vec_model.most_similar('영화', topn=10)
# Out:
# [('작품', 0.5626058578491211),
#  ('블록버스터', 0.5355560183525085),
#  ('명화', 0.5216415524482727),
#  ('수작', 0.5114963054656982),
#  ('블럭버스터', 0.5023318529129028),
#  ('영환', 0.4961312413215637),
#  ('대작', 0.4729803502559662),
#  ('엉화', 0.4661056399345398),
#  ('사례', 0.45896366238594055),
#  ('재료를', 0.44881749153137207)]

# %%
len(doc2vec_model.docvecs)
# Out:
# 14

# %%
for idx, doctag in sorted(doc2vec_model.docvecs.doctags.items(), key=lambda x:x[1].offset):
    print(idx, doctag)
# Out:
# MOVIE_72523 Doctag(offset=0, word_count=95807, doc_count=10187)
# MOVIE_59845 Doctag(offset=1, word_count=145728, doc_count=13095)
# MOVIE_109753 Doctag(offset=2, word_count=203777, doc_count=10361)
# MOVIE_45321 Doctag(offset=3, word_count=296181, doc_count=26915)
# MOVIE_45290 Doctag(offset=4, word_count=780093, doc_count=48273)
# MOVIE_47385 Doctag(offset=5, word_count=415014, doc_count=41653)
# MOVIE_78726 Doctag(offset=6, word_count=327881, doc_count=20615)
# MOVIE_89218 Doctag(offset=7, word_count=390257, doc_count=20080)
# MOVIE_47528 Doctag(offset=8, word_count=140321, doc_count=13397)
# MOVIE_75397 Doctag(offset=9, word_count=237917, doc_count=16444)
# MOVIE_48246 Doctag(offset=10, word_count=237510, doc_count=21912)
# MOVIE_140695 Doctag(offset=11, word_count=320033, doc_count=23998)
# MOVIE_72054 Doctag(offset=12, word_count=380546, doc_count=25748)
# MOVIE_102817 Doctag(offset=13, word_count=26550, doc_count=1864)

# %%
doc2vec_model.docvecs.most_similar('MOVIE_59845')
# Out:
# [('MOVIE_140695', 0.33166900277137756),
#  ('MOVIE_48246', 0.3011544346809387),
#  ('MOVIE_89218', 0.29501283168792725),
#  ('MOVIE_78726', 0.2935372292995453),
#  ('MOVIE_109753', 0.29165226221084595),
#  ('MOVIE_102817', 0.25933074951171875),
#  ('MOVIE_75397', 0.22235943377017975),
#  ('MOVIE_45321', 0.2216598093509674),
#  ('MOVIE_45290', 0.2202378362417221),
#  ('MOVIE_72054', 0.1946040391921997)]

# %%
doc2vec_model.docvecs.most_similar(1)
# Out:
# [('MOVIE_140695', 0.33166900277137756),
#  ('MOVIE_48246', 0.3011544346809387),
#  ('MOVIE_89218', 0.29501283168792725),
#  ('MOVIE_78726', 0.2935372292995453),
#  ('MOVIE_109753', 0.29165226221084595),
#  ('MOVIE_102817', 0.25933074951171875),
#  ('MOVIE_75397', 0.22235943377017975),
#  ('MOVIE_45321', 0.2216598093509674),
#  ('MOVIE_45290', 0.2202378362417221),
#  ('MOVIE_72054', 0.1946040391921997)]

# %%
list(doc2vec_model.docvecs.doctags)
# Out:
# ['MOVIE_78726',
#  'MOVIE_47385',
#  'MOVIE_75397',
#  'MOVIE_72054',
#  'MOVIE_48246',
#  'MOVIE_45290',
#  'MOVIE_109753',
#  'MOVIE_72523',
#  'MOVIE_47528',
#  'MOVIE_89218',
#  'MOVIE_102817',
#  'MOVIE_59845',
#  'MOVIE_140695',
#  'MOVIE_45321']

# %%
list(doc2vec_model.docvecs.doctags.items())[:5]
# Out:
# [('MOVIE_78726', Doctag(offset=6, word_count=327881, doc_count=20615)),
#  ('MOVIE_47385', Doctag(offset=5, word_count=415014, doc_count=41653)),
#  ('MOVIE_75397', Doctag(offset=9, word_count=237917, doc_count=16444)),
#  ('MOVIE_72054', Doctag(offset=12, word_count=380546, doc_count=25748)),
#  ('MOVIE_48246', Doctag(offset=10, word_count=237510, doc_count=21912))]

# %% [markdown]
# ### Doc2Vec 해석하기

# %%
import pickle

with open(id2movie_fname, 'rb') as f:
    idx2movie = pickle.load(f)
    
movie2idx = {name:movie_idx for movie_idx, name in idx2movie.items()}

# %%
movie2idx
# Out:
# {'측정하다': '43660',
#  '후퇴': '27313',
#  '정화': '121154',
#  '할머니의 시계': '137600',
#  '이브와 파이어 호스': '50036',
#  '가상성': '87455',
#  '메가포스군단': '23977',
#  '가쵸 딜로': '27452',
#  '다라비 다이어리': '104785',
#  '엘레나와 남자들': '94843',
#  '블랙메일링 산타': '77028',
#  '더 밸리': '113708',
#  '드그래시 하이': '76184',
#  '극장판 헌터X헌터 : 더 라스트 미션': '119985',
#  '톰 쿨': '109495',
#  '핸드메이드 위드 러브 프롬 프랑스': '130480',
#  '가장 위험한 해': '10552',
#  '헤일로 레전드': '80645',
#  '하우 투 스타트 유어 오운 컨트리': '78633',
#  '모모큔 소드': '127717',
#  '그랜드파스 매지컬 토이즈': '120724',
#  '기동타격대': '14555',
#  '룬': '80199',
#  '사랑의 계절': '21339',
#  '백전보산하': '73983',
#  '메뉴팩쳐링 스토크': '94965',
#  '시선의 기억': '99368',
#  '천상의 시계': '30880',
#  '당신이 고용주라면 시각장애인을 고용하시겠습니까?': '53572',
#  '롱 스토리 쇼트': '85273',
#  '요나 - 베기테일 무비': '36026',
#  '하트 앤 본즈': '87055',
#  '해탄적일천': '16064',
#  '세여자': '89351',
#  '신부일기': '21758',
#  '자니 이거': '43244',
#  '어느 사진가의 기억': '130032',
#  '나폴리, 나폴리, 나폴리': '70625',
#  '더 퍼플 어니언': '121687',
#  '안나의 랑데부': '29473',
#  '데드 맨': '19100',
#  '고잉 다운 인 라-라 랜드': '93709',
#  '걸즈 걸즈 걸즈': '82007',
#  '사뿐히 밟으소서': '54669',
#  '축가': '95890',
#  '나무소년': '103811',
#  '엄마는 나의 분신': '144558',
#  '라스트 블릿': '25575',
#  'weeping men': '50481',
#  '그림자 살인': '36188',
#  '이매망량': '42432',
#  '다이어리 오브 헝거': '132704',
#  '협녀유룡': '14899',
#  '더 베스트 이즈 옛 투 컴': '79990',
#  '열아홉 순정': '61240',
#  '통행 시계(발터 벤야민에게 바침)': '91829',
#  '바란': '87412',
#  '디소더': '110296',
#  '부도바 드니아': '124578',
#  '쥬얼 라버리': '99870',
#  '왕과 상노': '22383',
#  '만수야 그동안 잘 있었느냐?': '35354',
#  '선택은 없다 - 일과 양육': '46242',
#  '양을 세다': '144808',
#  '사슬을 풀고': '35437',
#  '제3성전': '114753',
#  '잃어버린 면사포': '22750',
#  '더 스피커': '119781',
#  '세이비어 오브 더 포레스트': '63687',
#  '체육대학': '97814',
#  '에메랄드': '12694',
#  '포기브미': '118594',
#  '시크릿 월드': '91268',
#  '어 롱 웨이 프럼 홈': '110418',
#  '사트리아 가루다 BIMA-X': '136781',
#  '스태그': '103679',
#  '히믈러 프로젝트': '40842',
#  '주전': '122983',
#  '커뮤니티 5': '109742',
#  '침묵 속에': '127245',
#  '즐거운 자전거 하이킹': '98890',
#  '까치 며느리': '90089',
#  '롤란도 빌라존의 헨델 아리아': '139625',
#  '동방노호': '11843',
#  '샘스 인 럭': '97789',
#  '의혹의 밤': '12661',
#  '웬 콜스 더 하트 시즌2': '138061',
#  '추수기': '40958',
#  '마틸다': '18934',
#  '고고한 메스': '76104',
#  '진노의 날': '127748',
#  '소금장수': '21609',
#  '사랑의 종합병원': '11718',
#  '첩혈남아': '17900',
#  '로라의 정사': '25080',
#  '20 센티미터': '48705',
#  '체인지 소동': '24959',
#  '노 웨이 백': '25501',
#  '언디스커버드 컨트리': '123145',
#  '베컴의 모든 것': '40191',
#  '회오리 바람 식당의 밤': '119391',
#  '페이 2 플레이': '128305',
#  '맬리스': '16228',
#  '플라이트 오브 더 버터플라이즈': '101021',
#  '자유롭게 움직여!': '60698',
#  '씬 아이스': '53503',
#  '체리': '91860',
#  '현빈': '43701',
#  '핑거 러닝': '132229',
#  '파이널 쏘우': '70247',
#  '런어웨이 호스': '69747',
#  '악녀의 저주': '28056',
#  '엘리자베스 테일러 전기': '76068',
#  '장화홍련': '53310',
#  '사살 명령': '28484',
#  '커맨더 앤 치프': '82553',
#  '필링 더 파인낸셜 갭': '110013',
#  '가샤폰 코로코로': '140484',
#  '타임 투 다이': '28225',
#  "원 에스키모 '선택받은 자'": '77417',
#  '브로큰 스레드': '66246',
#  '영희씨': '130408',
#  '타잔과 인어': '19253',
#  '레너드 인 슬로우 모션': '136521',
#  '왓 이즈 투 비 던?': '116500',
#  '니어 데스 익스피리언스': '128665',
#  '신성한 봄': '97411',
#  '오름투어': '129320',
#  '사무라이 참프루': '67670',
#  '본드를 마시는 아이들': '31009',
#  '디스 원트 허트 어 빗': '76639',
#  '모든 것이 F가 된다 THE PERFECT INSIDER': '143252',
#  '여존광룡': '26158',
#  '내 가슴 속의 락앤롤': '68401',
#  '디 아워 시즌1': '91151',
#  '갓즈 포켓': '119627',
#  '라디칼스': '104608',
#  '안나에 대하여': '139552',
#  '달려라 밀카 달려': '111982',
#  '레이디 비 굿': '43264',
#  '비트윈 더 시트': '57540',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄': '123095',
#  '도덕색녀': '141993',
#  '더 스톤': '110235',
#  '브레싱 인 디스가이즈': '116593',
#  '셉템버 테입': '39354',
#  '야수의 습지': '45025',
#  '민즈 투 언 엔드': '133781',
#  '스폰초이 피스포초이': '88333',
#  '코코 니 이즈미 아리': '80598',
#  '패스 어웨이': '16682',
#  '보스톤에서 온 두 자매': '47837',
#  '도박사와 유부녀': '28145',
#  '페이퍼 타이거': '82916',
#  '최후의 전사': '13318',
#  '꽃돼지': '127624',
#  '톰 소여': '44463',
#  '스플라이스': '52777',
#  '감각의 제국': '16617',
#  '상상고양이': '144328',
#  'Earthlings': '131802',
#  '첫인상': '80020',
#  '아르벤투르': '140569',
#  '부드럽게 안아줘': '55478',
#  '28 루 브리차우트': '123939',
#  '뇌세포': '80094',
#  '구름의 남쪽': '40608',
#  '미스터 미라클': '141198',
#  '황야의 스트렌저': '30026',
#  '더 라스트 에너미': '87043',
#  '파이널 숏': '114788',
#  '콘크리트': '109316',
#  '라잇 히어 라잇 나우': '135480',
#  '희양양과 회태랑': '117902',
#  '엘리노어 릭비: 그남자 그여자': '124290',
#  'An Urban Story': '122857',
#  '레퍼레이션': '129124',
#  '지옥까지 10초': '42628',
#  '레벨스 위드 어 코즈': '99521',
#  '슈파다이크 미츠 마담 엑스': '72992',
#  '너와 함께': '122696',
#  '수평적 경계': '52873',
#  '사랑 마을 사람들': '51422',
#  '비둘기의 꿈': '94530',
#  '레드라인': '54173',
#  '지금은 죽을 때가 아니다': '23039',
#  '조이풀 노이즈': '84844',
#  '드라마 스페셜 - 환향-쥐불놀이': '101116',
#  '대드': '85234',
#  '겟 하드': '130976',
#  '만약 내가 소중하지 않다면': '99479',
#  '바스켓볼 걸프렌드': '139387',
#  '블로고그': '71340',
#  '아기와 나': '49692',
#  '샤일로 3': '60842',
#  '더 이터널 프리젠트': '82528',
#  'Tuppe tuppe, Marescia!': '128677',
#  '로미와 미셀': '24780',
#  '몬트리올 좀비': '112490',
#  '하층민들': '24132',
#  '공감각': '125660',
#  '투 스텝': '130516',
#  '엔 엘 인솜니오': '74860',
#  '여귀전신': '15797',
#  '첩혈무적': '28081',
#  'Why Not?': '81964',
#  '액트 오브 비트레이얼': '17597',
#  '나의 스타가 우리 집에 찾아왔다': '126773',
#  '레퓨지 프롬 더 스톰': '127456',
#  '삐뚤빼뚤': '132964',
#  '아메리칸 버티고': '67798',
#  '문디알: 더 하이스트 스테이크스': '116758',
#  '더 콜러': '81011',
#  '그리고 그 후': '37595',
#  '조용한 사랑': '127149',
#  '한국학생운동사 제1부 저물어가는 1989년': '48917',
#  '더 프리 스피치 아포칼립스': '144788',
#  '알레그로 논 트로포': '29519',
#  '노말 라이프': '67651',
#  '사랑을 합시다': '10527',
#  '샤멘바나': '97012',
#  '투마스트': '137099',
#  '팀 탈리반': '72147',
#  '모스라 2': '73780',
#  '앤드류 짐먼의 이상한 음식': '82723',
#  '사이먼의 탐험 여행': '28660',
#  '파더 오브 더 프라이드': '133354',
#  '졸업 시험': '22977',
#  '대디 데이 케어': '36674',
#  '누군가 유에프오': '62431',
#  '조지아 룰': '61641',
#  '악령의 밤 2': '12618',
#  '더 플로그스타 로아': '109529',
#  '이혼 증서': '37836',
#  '원피스 3D : 밀짚모자 체이스': '84083',
#  'TV 맨: 더 서치 포 더 라스트 인디펜던트 딜러': '115994',
#  '메모리즈 오프 3.5 : 추억의 저편으로': '94417',
#  '인 프라하': '111466',
#  '프리랜서': '83366',
#  '레이지-이카리': '68121',
#  '서든 데쓰': '17342',
#  '꿈꾸는 정원': '36183',
#  '남자는 괴로워 17 - 토라의 석양과 일출': '57120',
#  '그린 포르노 - 잠자리': '46227',
#  '하나사키 마이가 잠자코 있지 않아 시즌2': '137773',
#  '테크워 4': '26607',
#  '사랑에 관한 짧은 습작': '48347',
#  '옐로우 엠': '46870',
#  '중화영웅': '19205',
#  '바더/베커 - 파터 란트': '86489',
#  '더 플라스틱 페스트': '121339',
#  '더 히어로: 러브 스토리 오브 어 스파이': '110377',
#  '개미 군단': '49622',
#  '불량 소년 3,000 명의 총 번 (머리)': '93724',
#  '미싱 앳 17': '119310',
#  '에스트라다의 미망인': '27926',
#  '조선해협': '22967',
#  '매매꾼': '20748',
#  '생일소년': '114079',
#  '미스터 빈': '19630',
#  '스크림 오브 더 비키니': '54676',
#  '스캔달: 신 인 더 시티': '81276',
#  '리벤지 2': '98106',
#  '대단한 젊음': '49330',
#  '랩소디에스': '96187',
#  '정글보이 봄바 3': '68729',
#  '변형': '99250',
#  '짜라파파': '32102',
#  '쾌걸 구변신': '23336',
#  '새로 지은 성': '78409',
#  '보디 랭귀지': '28264',
#  '트루 블러드 시즌6': '107902',
#  '극장판 메이저 : 우정의 강속구': '51877',
#  '에이전트 카터 시즌2': '138989',
#  '더 블랙 룸': '135450',
#  '일이사 군부대': '22743',
#  '세이브': '95117',
#  '톨 테일': '25530',
#  '닥터 스파인': '91431',
#  '러브 칵테일': '29842',
#  '류세이 과장': '64372',
#  '질문은 이제 그만!': '89469',
#  '슬랙조': '142941',
#  '광복70년 특집 매그넘 사진작가 대한민국 2년의 기록': '142828',
#  '더스티 투 글로리': '40421',
#  '이스트 L.A 스토리': '13450',
#  '사랑할 때와 이별할 때': '10320',
#  '이츠 베터 투 점프': '112359',
#  '찰리의 진실': '115254',
#  '헤드스': '24863',
#  '더 프라이스 오브 플라워스': '79027',
#  '늦은 여름': '41448',
#  '콜 걸 오브 크툴후': '132447',
#  '하드바디 2': '63259',
#  '드라마 스페셜 - 내가 결혼하는 이유': '122577',
#  '더 댄스 포 베서니': '111432',
#  '정용화의 홀로그램': '135356',
#  '호비와 쿠우의 어드벤처 : 고래의 노래': '122516',
#  '다이어트': '75765',
#  '더 하우스 아이 리브 인': '90975',
#  '이효종씨 가족의 저녁식사': '37281',
#  '졸업사진': '99085',
#  '메탈 베이블레이드 2': '103372',
#  '고민을 많이 하면 빨리 죽는다': '122697',
#  '누렉': '96176',
#  '스리맨나레이아나': '98966',
#  '더 멘드': '125472',
#  '전쟁과 평화 1부': '18755',
#  '킬러 크러쉬': '144322',
#  '마그마처럼': '66805',
#  '아이 소우 더 선': '72021',
#  '셀프 포트레이트 위드 어 디어': '94092',
#  '사령 - 리케의 저주': '67615',
#  '블러드배스 앳 더 하우스 오브 데스': '81309',
#  '이것이 진짜 공부다!': '127306',
#  '틱킹': '139379',
#  '다이렉팅 에디': '104634',
#  '아웃 오브 플레이': '96179',
#  '모자 도둑': '100484',
#  '선데이 조깅': '88887',
#  '스웨어워드': '143676',
#  '호텔 알파 마이크': '87624',
#  '여름날 파티에서 대학살 2': '14599',
#  '젊은 도시': '22893',
#  '바퀴': '116289',
#  '우리 사랑하는 동안': '93234',
#  '카바레 부인': '23321',
#  '화끈한 가족': '121188',
#  '미트 로프 - 쓰리 뱃 리브': '52956',
#  '올 폴 다운': '102585',
#  '재즈 송': '51987',
#  '트리부': '80325',
#  '보와니 분기점': '13227',
#  '와일드 차일드': '64014',
#  '미션 블루': '121310',
#  '부부 탐정': '73030',
#  '트로로사': '29804',
#  '크로커다일': '132480',
#  '모나 리자': '142908',
#  '가드 47번': '70320',
#  '우린 액션배우다': '68934',
#  '인 클로울': '12647',
#  '연구개': '94554',
#  '원정경기 가던 길': '64039',
#  '애살': '42051',
#  '나는 왕이다': '20056',
#  '키노 99': '59366',
#  '800 킬로미터의 차이 - 로망스': '50995',
#  '카페 느와르': '51825',
#  '이것은 다큐멘터리가 아니다': '53202',
#  '용권': '31601',
#  '대니 덱체어': '39383',
#  '창 밖의 여자': '23104',
#  '시간이 머무는 그 자리': '90617',
#  '리치 포 미': '72656',
#  'Natan': '64331',
#  '베일드 보이스': '139277',
#  '쓰리 바이어런트 피플': '63548',
#  '여죄수 사소리 2 - 41호 감방': '47115',
#  '한복 입은 남자': '144230',
#  '양철 지붕 위의 여자': '40724',
#  '인플루엔자': '66517',
#  '뮤비뱅크 스타더스트 1': '136944',
#  '키즈 플레이그라운드': '49222',
#  '아니마토': '77492',
#  '스테이크': '67889',
#  '원숭이의 해': '40438',
#  '젤리 피쉬': '113316',
#  '무단이탈': '84471',
#  '크리스마스 캐롤': '32908',
#  '몽실이': '69446',
#  '내 이름은 조니가 아니다': '71921',
#  '맥리벨': '42578',
#  '가슴 배구단': '53065',
#  '치': '115738',
#  '페티쉬': '69918',
#  '워킹 맨': '138871',
#  '민검사와 여선생': '20903',
#  '리댁티드': '68737',
#  '피부색깔 꿈': '90679',
#  '여의사의 유출본 - 얼굴': '141494',
#  '해로 하우스 11번지': '12876',
#  '피카소의 비밀': '35606',
#  '이프 아이 해드 노운 아이 워즈 어 지니어스': '67432',
#  '고요한 거리 벚꽃의 나라': '68503',
#  '스톰 인 썸머': '46230',
#  '리퍼 매드니스 - 영화 뮤지컬': '67837',
#  '다크 리얼리티': '106759',
#  '신 과수연의 여자 5': '102563',
#  '도돈굴천': '45295',
#  '라 메종 올가': '104754',
#  '고너스': '77759',
#  '황야의 무법자': '10069',
#  '두유 원트 디 엘리펀트 뮤직': '93648',
#  '드라마 스페셜 - 내가 술을 마시는 이유': '131498',
#  '노비너': '89527',
#  '석양의 불청객': '21551',
#  '다만 악에서 구하옵소서': '71280',
#  '호모 파베르': '32301',
#  '릴 퀸퀸': '127242',
#  '나이트 비지터': '14677',
#  '부정 서류': '30874',
#  '바이 바이 러브': '25599',
#  '카우보이 Vs. 공산주의자': '77973',
#  '똥강아지': '114878',
#  '매표소, 그 안': '125163',
#  '인생 우등생': '22710',
#  '얀 겔의 위대한 실험': '109583',
#  '보화영웅': '34289',
#  '하우 위 라이브': '110959',
#  '루퍼스 웨인라이트: 프리머 도너': '80059',
#  '사랑을 빌려 드립니다': '21336',
#  '더 옐로우 비턴': '79074',
#  '파팅 숏': '67349',
#  '킵 어 모디스트 헤드': '98787',
#  '웰컴 투 F.L.': '142351',
#  '내 아내 이름은 모리스': '36558',
#  '사진, 찍어드립니다': '71655',
#  '얼굴이 붉어진다': '48550',
#  '모리투리': '67047',
#  'Hear You': '130326',
#  '드림즈 프럼 어 페트리파이드 헤드': '87273',
#  '굴리스 2': '27596',
#  '출가': '48839',
#  '러브 어게인': '73025',
#  '수연이': '79783',
#  '클럽 레인보우': '76785',
#  '푸자 키벤 아': '106713',
#  '여복성': '28655',
#  '문을 넘어서': '135999',
#  '미지의 히카리': '86840',
#  '잉크트': '115747',
#  '굿 보이!': '36845',
#  '아더와 미니모이3: 두 세계의 전쟁': '51055',
#  '미토코몬 제27부': '100332',
#  '더럽혀진 백의': '63799',
#  '버려진 작품들': '128553',
#  '정복자 한니발': '39136',
#  '10+4': '44649',
#  '로그 잼': '70865',
#  '프로덕션': '131345',
#  '세베로': '129526',
#  '트렌드 비콘즈': '132255',
#  '몬스터즈2: 죽음의 대륙': '121045',
#  '이프 유 러브 유어 칠드런': '134414',
#  '민스 알로르!': '102776',
#  '헤밍웨이 & 겔혼': '95213',
#  '비오는 날의 오후 세시': '21236',
#  '총알탄 사나이': '10450',
#  '빅 스펜더': '52151',
#  '빅 시그널': '99220',
#  '젊은 부부': '101112',
#  '샹티에 A': '123779',
#  '달려라 왕인지': '61609',
#  '남자 고교생의 일상': '113374',
#  '스타 트랙 6 - 미지의 세계': '10079',
#  '대출 챌린저': '96317',
#  '블러디 먼데이 시즌2': '86859',
#  '슬롬': '125618',
#  '우중산책': '29350',
#  '볼트 에이지': '56736',
#  '황야의 탈출': '28294',
#  '샤오산의 귀가': '29510',
#  '사랑에 빠진 재즈': '115263',
#  '캔터베리 이야기': '32025',
#  '월드 오브 러브': '57294',
#  '장-마리 스트라우브와 다니엘 위예': '75113',
#  '그 날 이후': '70976',
#  '디 아더 맨: F.W. 데 클라크 앤 디 엔드 오브 아파르트헤이트': '132598',
#  '메이나': '89533',
#  '전성계비': '76943',
#  '톰 브로코우 프레젠트: 브릿징 더 디바이드': '88441',
#  '서브휴먼': '90134',
#  '사투르날리아': '139236',
#  '13 미닛츠': '135703',
#  '앨리어스 메리 스미스': '128373',
#  '둠스데이 맨': '87081',
#  '헤어브레인드': '121774',
#  '에이리언 몬스터': '25840',
#  '로테르담 트라넨': '124731',
#  '허 럭 인 런던': '126844',
#  '절대연필': '143720',
#  '탄식의 소조': '23358',
#  '걸스 타운': '64806',
#  '월요일의 유카': '39927',
#  '셔라즈': '139095',
#  '무의식': '43070',
#  '히틀러의 비밀 북치기 작전': '106514',
#  '백발의 처녀': '21022',
#  '비브흐 아벡 메메 씨 세 뒤르': '62116',
#  '패션 불변의 법칙': '82716',
#  '에리나와 알렉스와 간이역': '12621',
#  '내일의 빛을 잡고 2': '81419',
#  '비틀 퀸 컨커 도쿄': '75846',
#  '써티 세컨즈 오버 도쿄': '30006',
#  '브레이킹 더 바우': '115795',
#  '친애하는': '68620',
#  '지구를 지켜요': '49433',
#  '완벽한 남편': '39533',
#  '방직성 경찰': '37522',
#  '로버타': '46717',
#  '드라마시티 - 엄마의 첫 사랑': '123224',
#  '섹스 컬처 파리': '110015',
#  '얀 사우덱': '49540',
#  '내 팔자가 상팔자': '20189',
#  '더 러브 송 오브 이스크라 프루프록': '81736',
#  '스트라이큰': '80756',
#  '천재견 해리': '97669',
#  '가족초상화': '90308',
#  '대필': '86033',
#  '어린 왕자': '39835',
#  '두 마리의 꽁치': '34748',
#  '타이투스': '28797',
#  '살인을 위한 시간': '29669',
#  '사라지는 숲의 세대': '139135',
#  '더 라잇 투 러브': '131017',
#  '가족은 괴로워': '144771',
#  '우슈 워리어': '122141',
#  '네서서리 이블': '70441',
#  '할로윈 5': '17664',
#  '활': '40603',
#  '미확인 미행물체': '43962',
#  '어 월드 낫 아워스': '98292',
#  '프레임업': '63669',
#  '왓츠 업': '89739',
#  '주피터문': '108760',
#  '탈북소년들 중국에 가다': '90762',
#  '독 안에 들어간 쥐': '17893',
#  '귀전인': '15538',
#  '페이스 오브 디 에너미': '124077',
#  '호텔 바빌론': '81899',
#  '검열된 목소리': '134594',
#  '난생처음 여행단': '117469',
#  '디스 이즈 마이 픽쳐 웬 아이 워즈 데드': '88093',
#  '대한민국 해양 대 탐험': '84292',
#  '나이트 홈': '138275',
#  '타키엔': '43098',
#  '핫 섬머': '46540',
#  '얀 모': '59919',
#  '모두를 위한 학교': '65514',
#  '피쉬 인 워터': '131998',
#  '최인호의 병태 만세': '23255',
#  '특급 살인': '77993',
#  '오챠드.5': '118057',
#  '보이즈 앤 후드': '16360',
#  '천둥의 아이': '13989',
#  '어웨이 위드 워즈': '52205',
#  '캘리포니아 스플릿': '63914',
#  '리버럴 아츠': '90934',
#  '누명': '27908',
#  '보위 이즈 인사이드': '113411',
#  '미트 더 피블스': '33002',
#  '치티 치티 뱅 뱅': '11085',
#  '투 어나더 엣지': '46781',
#  '영웅들의 날개짓': '14242',
#  '헤븐 센트': '141641',
#  '더 스페셜리스트': '138491',
#  '삼도 수군 통제사': '95609',
#  '갓 스쿼드': '134446',
#  '페스티벌': '112678',
#  '수호지 - 천하대인': '123017',
#  '페어런트 후드 시즌2': '99642',
#  '최초의 조선통신사 이예': '97698',
#  '파자마 게임': '46921',
#  '그들의 역습': '62202',
#  '디스 이즈 알레스카': '111804',
#  '악몽의 단편들': '40806',
#  '샹그리-라': '92850',
#  '스테츄 넘버': '87485',
#  '하치 이야기': '34497',
#  'SCTV 네트워크 90': '81555',
#  '석유의 길': '68747',
#  '대지여 말해다오': '20473',
#  '서브웨이 키즈 2002': '36122',
#  'Lune froide': '64704',
#  '나는 소망한다 내게 금지된 것을': '17600',
#  '성탄쾌락': '33391',
#  '릴리옴': '65976',
#  '우연한 방문객': '13718',
#  '시어지 포 더 소울': '89061',
#  '못다한 27번의 키스': '31005',
#  '오를리': '78454',
#  '드라마 스페셜 - 기묘한 동거': '113504',
#  '달 소년의 사랑': '79686',
#  '마젤란': '109232',
#  '토이랜드': '52206',
#  '베를린 마담 39': '16449',
#  '깊은 밤의 침묵': '17377',
#  '갈마': '11337',
#  '비행의 이론': '36434',
#  '수요일 04:45': '137122',
#  '다크 애즈 데이': '81058',
#  '어 사이트 포 소어 아이즈': '107295',
#  'Tabarly': '51739',
#  '퍼머넌트 노바라': '76760',
#  '저무는 방': '95636',
#  '난 분명히 당했다': '101520',
#  '샤도우 오브 더 화이트 나잇': '81813',
#  '설레셜 카멜': '136165',
#  '투 올 마이 프렌즈': '96717',
#  '스크리밍 미미': '113698',
#  '스가타 산시로 2': '43126',
#  '인사이드 잡': '75508',
#  '찬스 오브 스노우': '29594',
#  '클라리네티스트': '144531',
#  '티족': '61070',
#  '비팅 하트': '88614',
#  '머독 미스터리 시즌4': '103615',
#  '포켓몬 더 무비 XY 후파: 광륜의 초마신': '137010',
#  '마이 데드 보이프렌드': '124024',
#  '아웃 오브 더 클리어 블루 스카이': '102373',
#  '이너 뷰': '111220',
#  '징혼계사': '48000',
#  '윈터타임': '53511',
#  '우리동네 포르노스타': '111006',
#  '배낭을 멘 소년': '41064',
#  '강철의 사나이': '14431',
#  '게팅 업 : 더 템프트 원 스토리': '99911',
#  '본 투 다이': '133596',
#  '즐거운 경찰': '40077',
#  '아키라의 친구': '80138',
#  '닌자 마스크 2': '112495',
#  '마스터즈 오브 호러 시즌 2 에피소드 7 - 스크루플라이': '65692',
#  'K.G. 가라데 걸': '90508',
#  '미 앤 카민스키': '144896',
#  '멜빈과 하워드': '12771',
#  '애프터 더 폴': '119550',
#  '썬다운': '49125',
#  '더 카메라': '90187',
#  'Jan Saudek': '64673',
#  '디 아나키스트': '144082',
#  '투신전': '94438',
#  '하우스키핑': '134511',
#  '스파이더 킹덤': '73405',
#  '멕시코인이 사라진 날': '38790',
#  '올 세인츠': '54643',
#  '버즈 오브 어 페더': '119388',
#  '절귀': '40770',
#  '결혼이야기': '134109',
#  '쇼 미 더 머니': '94220',
#  '바가 비치': '118811',
#  '아이돌 마스터 무비 : 빛의 저편으로!': '121094',
#  '레이디 닌자': '32555',
#  '어 홀스 콜드 베어': '131487',
#  '엽전 도사와 젓가락 도사 2': '52974',
#  '가장자리': '106268',
#  '호협전': '16076',
#  '글로벌다큐멘터리 스파이 펭귄': '120026',
#  'Reste': '64637',
#  '비블로스': '114524',
#  '폴 인 더 딥 마운틴': '61900',
#  '꼬마 우편 배달부': '97245',
#  '남대여': '20120',
#  '주디': '104901',
#  '스톤 템플': '67518',
#  '로드 투 차이나': '15000',
#  '닉 스워드슨': '82923',
#  '유령 크누트': '44775',
#  '대혈투': '14661',
#  '루즈 시엘': '75858',
#  '메이아 호라 앤 더 헤드라인스 댓 비컴 헤드라인스': '133763',
#  '서유기3: 월광보합 리턴즈': '142323',
#  '대디 ABC': '121801',
#  '자매의 화원': '22782',
#  '주저앉은 도시': '111928',
#  '다크데이': '94678',
#  '굿 올드 보이즈': '133880',
#  '터미네이션스': '109405',
#  '침묵의 동반자': '33290',
#  '로댕이 죽음을 만났을 때': '48098',
#  '구보씨 일보': '67329',
#  '필름에이지: 더 스토리 오브 디센던트/올': '118331',
#  '챔피언스 오브 더 딥': '97676',
#  '신 의리없는 전쟁': '45345',
#  '에이티 레터스': '83148',
#  '다리가 불편한 여자': '58772',
#  '울려고 내가 왔던가': '22494',
#  '칠레 전투 제3부: 민중의 힘': '20343',
#  '에이리언 터미네이터 2': '62049',
#  '푸른 눈 그리고 작은 귀': '77659',
#  '마샤 앤 에델': '63715',
#  '내 딸 서영이': '96887',
#  "와다'": '143953',
#  '에스코트 2': '26924',
#  '토마토 대소동 - TV시리즈': '51580',
#  '스타 트렉: 엔터프라이즈': '53771',
#  '까마귀들': '92760',
#  '창조자': '78916',
#  '더 베스트 이어스 오브 아워 리브스': '85694',
#  '경비원': '143909',
#  '사녀': '21299',
#  '매투살렘 2': '26581',
#  '노아': '113935',
#  '천장무상': '28023',
#  '야성녀': '22014',
#  '어떻게 좀 안될까요 2': '126878',
#  '데스 콜': '26064',
#  '에밀의 방울': '98314',
#  '껴묻거리': '140262',
#  '해리가 한건 잡았을 때': '12891',
#  '6월의 산': '88144',
#  '남서쪽': '91814',
#  '위저드 배리스터즈 - 변마사 세실': '118605',
#  '신나는 동물농장': '62331',
#  '위트': '30782',
#  '더블갱저스': '120130',
#  'NMB48 게닌! THE MOVIE 오와라이 청춘걸스!': '112096',
#  '후쿠오카 연애백서 5': '103016',
#  '기타 레슨': '67267',
#  '올 얼론': '113905',
#  '쓰리 포 더 쇼': '46976',
#  '사랑의 대모험': '56007',
#  '워리어 어쌔신': '124228',
#  '슈퍼아이돌': '141706',
#  '스틸 앨리스': '120759',
#  '방가방가 햄토리 극장판 시리즈': '94663',
#  '러브 셔플': '52550',
#  '가을 소나기': '46644',
#  '엣 플레이 인 더 필즈 오브 더 로드': '27486',
#  '바다는 눈을 기다리지 않는다': '48248',
#  '인다 치트라': '139775',
#  '신사임당 (가제)': '129151',
#  '아이 러브 멜빈': '46876',
#  '나이트 오브 더 리빙 브레드': '123634',
#  '바이블 퀴즈': '108385',
#  '브루클린 다리 위의 하얀깃발': '135728',
#  '어 콜 투 액션': '108440',
#  '길을 간다': '29562',
#  '천상인간': '27275',
#  '재취업 프로젝트 - 나, 출근합니다': '130701',
#  '기타를 멘 철새': '89420',
#  '너와 나의 이야기 - 안녕 오늘은': '58744',
#  '일루미나투스': '134952',
#  '노로마 노 오야지': '117429',
#  '파더 앤 시스터': '78888',
#  '스카 티슈': '111947',
#  '패밀리 룰스': '49796',
#  '더 과이: 쇼트 필름': '139256',
#  '리미트': '110710',
#  '노킹 온 헤븐스 도어': '18871',
#  '가장 깨끗한 물': '64193',
#  '섹스팅': '86886',
#  '더 쓰리디-머신': '143598',
#  '유어 킬링 미': '141766',
#  '더 5': '99998',
#  '매뉴얼 오브 러브 3': '120151',
#  '디 에어 매트리스': '117666',
#  '두 개의 선': '74956',
#  '샷건 스토리즈': '67875',
#  '리오를 향하여': '28302',
#  '아웃핏': '38645',
#  '길 잃은 사람들': '53130',
#  '이카르트 드 콩듀잇': '114417',
#  '버니 앤 콜걸': '91856',
#  '하이 플레인스 윈터': '67405',
#  '잇츠 미, 힐러리: 더 맨 후 드류 엘로이즈': '134937',
#  '와라! 편의점': '100001',
#  '더 빅 오퍼레이터': '137503',
#  '락슈미': '119736',
#  '위층여자와 아래층남자': '122077',
#  '신의 도움이 필요해': '95318',
#  '은빛 바다': '128091',
#  '렛 유 얼웨이즈 싱, 마더!': '138696',
#  '산설': '96036',
#  '할버쉬타트': '31032',
#  '아메리칸 지져스': '116358',
#  '일렉트릭 라이트 원더랜드': '75580',
#  '보이지 않아…': '43407',
#  '올 인 굿 타임': '99456',
#  '더 버스 오브 락': '104263',
#  '생계': '54322',
#  '좀비의 순정': '76850',
#  '클로즈 투 유': '68143',
#  '피프틴': '138229',
#  '담배, 협력': '68096',
#  '랜드 오브 스톰스': '103349',
#  '레터 투 애나벨': '130557',
#  '타오 오브 스티브': '30714',
#  '맏며느리': '121153',
#  '바다의 에피소드': '129894',
#  '신나는 일요일': '17249',
#  '이보니 퍼레이드': '53386',
#  '우리결혼할까요?': '89557',
#  '카르타 비앙카 어 엔리코 게지': '105643',
#  '네페르티티, 리지나 델 닐로': '91353',
#  '나의 겨울 여행': '38933',
#  '언스크립티드': '56682',
#  '욱달부전기': '15874',
#  '로얄 스캔들': '35963',
#  '황금분할': '93617',
#  '바르자크': '83141',
#  '자레인 탈출': '46259',
#  'Mon meilleur amour': '64428',
#  '제로타임': '100662',
#  '매직 랜턴 싸이클': '90385',
#  '사비': '140648',
#  '바텔': '29267',
#  '맷 트로이 덴': '124593',
#  '보이스 에스테': '76084',
#  '솔시레': '142401',
#  '씨앗': '127681',
#  '라야 프로젝트': '70032',
#  '헐리우드 이즈 라이크 하이스쿨 위드 머니': '127908',
#  '겟 썸': '131081',
#  '나만의 행성 만들기': '143899',
#  '샬롯 대공 부인(디지털)': '100360',
#  '프랑켄슈타인 - 영혼 없는 삶': '18653',
#  '우나 호라 포 페보라': '91111',
#  '아웃 오브 더 블루': '32804',
#  '섹스 체크': '73364',
#  '오퍼레이션 X-70': '34686',
#  '힐': '79985',
#  '아메리카 101': '115787',
#  '왕자가 된 소녀들': '86912',
#  '미드나잇 모랄스': '128374',
#  '황혼의 애상': '23752',
#  '더 할로우 포인트': '110635',
#  '베니와 준': '16606',
#  '땡큐 마담 4 - 중출강호': '13749',
#  '아무도 모른다': '128780',
#  '백 벤치 스튜던트': '106309',
#  '옥스': '26101',
#  '벨라 도나': '26892',
#  '화이트 멕시코': '50687',
#  '인간 병기 인디오 2': '28235',
#  '미미': '142837',
#  '스트레인지 마스커레이드': '93333',
#  '슬래터하우스': '139502',
#  '웨이스팅 어웨이': '71464',
#  '현금은 내 것이다': '23621',
#  '대한민국 산악 구조대 - 국립공원 관리공단 구조교육': '137446',
#  '카드로 만든 집': '13508',
#  '문정왕후': '20875',
#  '선술집 유령': '11222',
#  '건우먼': '127765',
#  '빅 스타: 낫씽 캔 허트 미': '99834',
#  '스피릿트': '67608',
#  '시험비행': '95891',
#  '더 데드 씨': '104016',
#  '5인의 왼손잡이': '22362',
#  '왼손잡이 건맨': '29598',
#  '더 댄서 앤드 더 트램': '111217',
#  '리와얏': '91364',
#  '콰이어보이': '42638',
#  '더 이어스 오브 피에로': '129849',
#  '플라자': '110114',
#  '다다미 네장 반 신화대계': '91554',
#  '실험형사 토토리 1': '115474',
#  '수요일': '69575',
#  '우주 전함 야마토 - 시리즈 2': '21144',
#  '러블리 몰리': '87791',
#  '더 스토리텔러': '134532',
#  '빌': '143157',
#  '메리드 낫 데드': '72298',
#  '슬루이저 스픽스': '132723',
#  '페퍼민타': '71002',
#  '더 프리빌리지스 오브 어 차일드': '134521',
#  '세븐 데이즈 인 더 우드': '84433',
#  '더 퍼스트 타임': '90969',
#  '엔드게임': '116582',
#  '리딩 맨': '116675',
#  '진저 샌드': '111919',
#  'L.A.I.S.': '109676',
#  '더 캐러셀 패밀리': '124861',
#  '월드 트레져 3 - 유다 성배의 저주': '73453',
#  '인 디 에어': '53307',
#  '아이 캔 씨 유': '141120',
#  '스캔들 : 매우 충격적이고 부도덕한 사건': '107970',
#  '메르세데스 벤츠 - SL 블랙 CM': '100859',
#  '신밧드: 제 5의 항해': '86534',
#  '디센던트 오브 더 스노우 레오파드': '92965',
#  '짧은 기억': '127843',
#  '안녕! 친구야': '77615',
#  '흑룡 통첩장': '23798',
#  '루이스의 석유통': '108418',
#  '아모레 리쿠이도': '78715',
#  '서벌버나이트': '132234',
#  'OSS 117': '69760',
#  '치욕의 법정': '16586',
#  '모터링': '126996',
#  '인생은 어려워': '44830',
#  '피로 & 클렙토': '117967',
#  '응답하라 1988': '137377',
#  '더 플레이스 인 비트윈': '79211',
#  '최후의 방어선': '13224',
#  '지금과 옛날 이야기': '44793',
#  '나는 조진웅이다.': '63921',
#  '날아라 호빵맨 - 무지개 피라미드': '140757',
#  '크레이머 대 크레이머': '10629',
#  '블랙 캣 2': '24326',
#  '천사의 날개': '13889',
#  '모차르트, 클라리넷 5중주 A장조 K. 581': '141041',
#  '마니토': '57810',
#  '바람과 나무의 길': '48254',
#  '도그 세이브 더 퀸': '116727',
#  '러브, 뉴욕': '93790',
#  '토끼풀': '98851',
#  '소프트 셀': '98263',
#  '흑야괴객': '15492',
#  '고통의 씨앗': '89651',
#  '슬레잉 더 드래곤: 리로디드': '83655',
#  '캐서린 드 메디치 Part 2': '116081',
#  '아틀라스 어게인스트 더 사이크롭스': '73645',
#  '007 황금총을 가진 사나이': '10164',
#  '하트브레이커스': '32026',
#  '스토리 오브 Mr.러브': '111525',
#  '조-조': '108441',
#  '챌린지': '30434',
#  '어느날 밤에 생긴 일': '10357',
#  '립트!': '119346',
#  '워터 핸드': '86795',
#  '뱀파이어 다이어리 시즌6': '125212',
#  '리텐션': '119334',
#  '70년대 동시상영관으로': '88582',
#  '진부한 천사': '29163',
#  '우주전쟁 : 지구 최후의 날': '132379',
#  '위태로운 삶: 홍콩의 연인들': '74674',
#  '레퀴엠 포 로맨스': '98599',
#  '쟈티쉬워': '122134',
#  '천웅괴담': '96667',
#  '왈츠': '44559',
#  '선탠하는 사람들': '50275',
#  '블루이': '139883',
#  '징징의 선물': '60207',
#  '조금 불편한 그다지 불행하지 않은 0.24': '74807',
#  '점핑 더 브룸': '83549',
#  '킥커': '39252',
#  '아워프렌츠': '87572',
#  'Les noces de papier': '135909',
#  '크레이트 데이': '89480',
#  '미완의 현재': '36252',
#  '세대의 힘': '88578',
#  '프라이미벌 시즌4': '97294',
#  '맥베스': '135349',
#  '우리 동네 이발소에 무슨 일이 3': '137969',
#  '물': '63479',
#  '아시일편운': '42042',
#  '오징어와 고래': '51592',
#  '테리': '119131',
#  '루! 작은 신문': '129397',
#  '그랜드 세이트 패슨스': '38842',
#  '도브': '28909',
#  '크리스마스의 기적': '13857',
#  '햄버거 힐': '11958',
#  '어 팰러블 걸': '104850',
#  '더 라스트 패시지': '88011',
#  '베어 미': '108622',
#  '블리드': '105804',
#  '더 버스': '140532',
#  '로이드 여자를 꼬시는 법': '77519',
#  'OSS 117 : 카이로 - 스파이의 둥지': '61978',
#  '진다 바그': '117859',
#  '로스트 포 워즈': '102831',
#  '베닐드 혹은 성모': '28916',
#  '애정결핍이 두 남자에게 미치는 영향': '61025',
#  '사랑은 선율을 타고': '11010',
#  '텍사스 전기톱 학살 2': '16970',
#  '악몽의 골목': '63553',
#  '카사네': '138019',
#  '세이프티존': '25158',
#  '기죽지 마라': '72035',
#  '빈곤의 얼굴들2': '93420',
#  '벼랑 끝에 걸린 사나이': '14358',
#  '앙심정': '83983',
#  '나와 오손 웰스': '71496',
#  '해산식': '45406',
#  '깃티': '103060',
#  '옷장속의 츠쿠시 짱': '89680',
#  '댐 유어 아이즈': '123833',
#  '로베르토 수코': '32603',
#  '무슈 이 마담 퀴리': '99174',
#  '마담 드...': '61785',
#  '더 프로': '130934',
#  '보물섬': '90575',
#  '컴 앤 플레이': '118204',
#  '아이 러브 유 올': '116627',
#  '조선 느와르 - 이명세 형사 만들기': '54837',
#  'Adele Frelon est-elle la ?': '64742',
#  '피아골': '16197',
#  '천재소년 지미뉴트론 시즌1': '136665',
#  '3중대의 병사들': '10342',
#  '떠돌이 까치': '19590',
#  '슬립리스 나이츠 스토리': '89190',
#  '라이트, 아니마, 액션!': '126158',
#  '유계잡패군': '15881',
#  '천사의 엔진': '88594',
#  '저 언덕을 넘어서': '22860',
#  '피안': '71409',
#  '8미리 사이드 미': '54634',
#  '경천풍운': '27735',
#  '샤말 아저씨 가로등을 끄다': '99362',
#  '나의 적의 적': '44355',
#  '오모테산도 고교 합창부!': '141080',
#  '서버럴 프렌즈': '49246',
#  '제이몽': '101643',
#  '카프리카': '74726',
#  '아이 오브 이글': '17408',
#  '왓 더 데프 맨 허드': '141851',
#  '게토': '61872',
#  '애증의 종말': '18171',
#  ...}

# %%
doc2vec_model.docvecs.doctags
# Out:
# {'MOVIE_102817': Doctag(offset=13, word_count=26550, doc_count=1864),
#  'MOVIE_109753': Doctag(offset=2, word_count=203777, doc_count=10361),
#  'MOVIE_140695': Doctag(offset=11, word_count=320033, doc_count=23998),
#  'MOVIE_45290': Doctag(offset=4, word_count=780093, doc_count=48273),
#  'MOVIE_45321': Doctag(offset=3, word_count=296181, doc_count=26915),
#  'MOVIE_47385': Doctag(offset=5, word_count=415014, doc_count=41653),
#  'MOVIE_47528': Doctag(offset=8, word_count=140321, doc_count=13397),
#  'MOVIE_48246': Doctag(offset=10, word_count=237510, doc_count=21912),
#  'MOVIE_59845': Doctag(offset=1, word_count=145728, doc_count=13095),
#  'MOVIE_72054': Doctag(offset=12, word_count=380546, doc_count=25748),
#  'MOVIE_72523': Doctag(offset=0, word_count=95807, doc_count=10187),
#  'MOVIE_75397': Doctag(offset=9, word_count=237917, doc_count=16444),
#  'MOVIE_78726': Doctag(offset=6, word_count=327881, doc_count=20615),
#  'MOVIE_89218': Doctag(offset=7, word_count=390257, doc_count=20080)}

# %%
for similar in doc2vec_model.docvecs.most_similar('MOVIE_45290'):
    print(similar)
# Out:
# ('MOVIE_72054', 0.5183938145637512)
# ('MOVIE_47528', 0.38170790672302246)
# ('MOVIE_89218', 0.2922521233558655)
# ('MOVIE_75397', 0.259696364402771)
# ('MOVIE_109753', 0.24901366233825684)
# ('MOVIE_59845', 0.2202378213405609)
# ('MOVIE_48246', 0.18558764457702637)
# ('MOVIE_140695', 0.18136835098266602)
# ('MOVIE_47385', 0.11665219813585281)
# ('MOVIE_72523', 0.11536259204149246)

# %%
for doctag in doc2vec_model.docvecs.doctags:
    movie_idx = doctag.split('_')[1]
    name = idx2movie.get(movie_idx, -1)
    print(movie_idx, '\t', name)
# Out:
# 78726 	 도둑들
# 47385 	 국가대표
# 75397 	 미스터 고
# 72054 	 다크 나이트 라이즈
# 48246 	 7광구
# 45290 	 인터스텔라
# 109753 	 해무
# 72523 	 고사 두 번째 이야기: 교생실습
# 47528 	 해리 포터와 죽음의 성물 - 2부
# 89218 	 베를린
# 102817 	 해적: 바다로 간 산적
# 59845 	 박쥐
# 140695 	 럭키
# 45321 	 해운대

# %%
def id2name(similar):
    idx = similar[0].split('_')[1]
    return (idx2movie.get(idx, 'unknown'), idx, similar[1])


print('인터스텔라\n')

for similar in doc2vec_model.docvecs.most_similar('MOVIE_45290'):
    print(id2name(similar))
# Out:
# 인터스텔라
#
# ('다크 나이트 라이즈', '72054', 0.5183938145637512)
# ('해리 포터와 죽음의 성물 - 2부', '47528', 0.38170790672302246)
# ('베를린', '89218', 0.2922521233558655)
# ('미스터 고', '75397', 0.259696364402771)
# ('해무', '109753', 0.24901366233825684)
# ('박쥐', '59845', 0.2202378213405609)
# ('7광구', '48246', 0.18558764457702637)
# ('럭키', '140695', 0.18136835098266602)
# ('국가대표', '47385', 0.11665219813585281)
# ('고사 두 번째 이야기: 교생실습', '72523', 0.11536259204149246)

# %%
print('국가대표\n')
for similar in doc2vec_model.docvecs.most_similar('MOVIE_47385'):
    print(id2name(similar))
# Out:
# 국가대표
#
# ('해운대', '45321', 0.7804709672927856)
# ('미스터 고', '75397', 0.5387098789215088)
# ('7광구', '48246', 0.3739200830459595)
# ('해적: 바다로 간 산적', '102817', 0.37021905183792114)
# ('고사 두 번째 이야기: 교생실습', '72523', 0.32833945751190186)
# ('해리 포터와 죽음의 성물 - 2부', '47528', 0.2908831238746643)
# ('럭키', '140695', 0.2793704867362976)
# ('베를린', '89218', 0.20493870973587036)
# ('해무', '109753', 0.17311882972717285)
# ('박쥐', '59845', 0.16962012648582458)

# %% [markdown]
# ## t-SNE

# %%
doc2vec_model.docvecs.doctag_syn0.shape, type(doc2vec_model.docvecs.doctag_syn0)
# Out:
# ((14, 100), numpy.ndarray)

# %%
index2tag = [doc2vec_model.docvecs.index_to_doctag(i) for i in range(172)]
print(index2tag[:5])
# Out:
# ['MOVIE_72523', 'MOVIE_59845', 'MOVIE_109753', 'MOVIE_45321', 'MOVIE_45290']

# %%
tag2index = {tag:index for index, tag in enumerate(index2tag)}
tag2index
# Out:
# {14: 14,
#  15: 15,
#  16: 16,
#  17: 17,
#  18: 18,
#  19: 19,
#  20: 20,
#  21: 21,
#  'MOVIE_102817': 13,
#  23: 23,
#  24: 24,
#  25: 25,
#  26: 26,
#  27: 27,
#  28: 28,
#  29: 29,
#  30: 30,
#  31: 31,
#  32: 32,
#  33: 33,
#  34: 34,
#  35: 35,
#  36: 36,
#  37: 37,
#  38: 38,
#  39: 39,
#  40: 40,
#  41: 41,
#  42: 42,
#  43: 43,
#  44: 44,
#  45: 45,
#  46: 46,
#  47: 47,
#  48: 48,
#  49: 49,
#  50: 50,
#  51: 51,
#  52: 52,
#  53: 53,
#  54: 54,
#  'MOVIE_59845': 1,
#  56: 56,
#  57: 57,
#  58: 58,
#  59: 59,
#  60: 60,
#  61: 61,
#  62: 62,
#  63: 63,
#  64: 64,
#  65: 65,
#  66: 66,
#  67: 67,
#  68: 68,
#  69: 69,
#  70: 70,
#  71: 71,
#  72: 72,
#  73: 73,
#  74: 74,
#  75: 75,
#  76: 76,
#  77: 77,
#  78: 78,
#  79: 79,
#  80: 80,
#  81: 81,
#  82: 82,
#  83: 83,
#  84: 84,
#  85: 85,
#  86: 86,
#  87: 87,
#  88: 88,
#  89: 89,
#  90: 90,
#  91: 91,
#  92: 92,
#  93: 93,
#  94: 94,
#  95: 95,
#  96: 96,
#  97: 97,
#  98: 98,
#  99: 99,
#  100: 100,
#  101: 101,
#  'MOVIE_72054': 12,
#  'MOVIE_140695': 11,
#  104: 104,
#  105: 105,
#  106: 106,
#  103: 103,
#  108: 108,
#  109: 109,
#  110: 110,
#  111: 111,
#  112: 112,
#  113: 113,
#  114: 114,
#  115: 115,
#  116: 116,
#  117: 117,
#  118: 118,
#  119: 119,
#  120: 120,
#  121: 121,
#  122: 122,
#  123: 123,
#  124: 124,
#  125: 125,
#  126: 126,
#  127: 127,
#  128: 128,
#  129: 129,
#  130: 130,
#  107: 107,
#  132: 132,
#  22: 22,
#  134: 134,
#  135: 135,
#  136: 136,
#  137: 137,
#  138: 138,
#  139: 139,
#  140: 140,
#  141: 141,
#  142: 142,
#  143: 143,
#  144: 144,
#  145: 145,
#  146: 146,
#  147: 147,
#  'MOVIE_89218': 7,
#  149: 149,
#  150: 150,
#  'MOVIE_45321': 3,
#  152: 152,
#  153: 153,
#  154: 154,
#  155: 155,
#  156: 156,
#  157: 157,
#  158: 158,
#  159: 159,
#  160: 160,
#  161: 161,
#  162: 162,
#  163: 163,
#  164: 164,
#  165: 165,
#  166: 166,
#  167: 167,
#  168: 168,
#  169: 169,
#  170: 170,
#  171: 171,
#  'MOVIE_45290': 4,
#  'MOVIE_47385': 5,
#  'MOVIE_48246': 10,
#  'MOVIE_72523': 0,
#  131: 131,
#  133: 133,
#  'MOVIE_75397': 9,
#  'MOVIE_109753': 2,
#  55: 55,
#  148: 148,
#  151: 151,
#  'MOVIE_47528': 8,
#  'MOVIE_78726': 6,
#  102: 102}

# %%
index2name = [idx2movie.get(tag.split('_')[1], -1) for tag in index2tag]
print(index2name[:5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-80e768ab18b0> in <module>()
#       1 tag2index = {tag:index for index, tag in enumerate(index2tag)}
#       2
# ----> 3 index2name = [idx2movie.get(tag.split('_')[1], -1) for tag in index2tag]
#       4 print(index2name[:5])
#
# <ipython-input-22-80e768ab18b0> in <listcomp>(.0)
#       1 tag2index = {tag:index for index, tag in enumerate(index2tag)}
#       2
# ----> 3 index2name = [idx2movie.get(tag.split('_')[1], -1) for tag in index2tag]
#       4 print(index2name[:5])
#
# AttributeError: 'int' object has no attribute 'split'

# %%
# %%time 

from sklearn.manifold import TSNE

tsne = TSNE(n_components=2)
y_tsne = tsne.fit_transform(doc2vec_model.docvecs.doctag_syn0)

y_tsne.shape

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

list(matplotlib.font_manager.get_fontconfig_fonts())[:5]

krfont = {'family' : 'nanumgothic', 'weight' : 'bold', 'size'   : 10}
matplotlib.rc('font', **krfont)

# %%
plt.figure(figsize=(15,10))
plt.scatter(y_tsne[:,0], y_tsne[:,1], color='yellow')

similars = [tag for tag, _ in doc2vec_model.docvecs.most_similar('MOVIE_134963')] + ['MOVIE_134963']

for tag in similars:
    index = tag2index.get(tag, -1)
    if index == -1:
        continue
    name = index2name[index]
    plt.annotate(name, (y_tsne[index, 0], y_tsne[index, 1]))

plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(y_tsne[:,0], y_tsne[:,1], color='yellow')

similars = [tag for tag, _ in doc2vec_model.docvecs.most_similar('MOVIE_93728')] + ['MOVIE_93728']

for tag in similars:
    index = tag2index.get(tag, -1)
    if index == -1:
        continue
    name = index2name[index]
    plt.annotate(name, (y_tsne[index, 0], y_tsne[index, 1]))

plt.show()
